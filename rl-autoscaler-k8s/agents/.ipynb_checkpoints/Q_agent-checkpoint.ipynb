# %%
# !pip install -e ../gym_k8s_real
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/li/rl-autoscaler-k8s/gym_k8s_real
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym in /home/li/.local/lib/python3.9/site-packages (from gym-k8s-real==0.0.1) (0.21.0)
# Requirement already satisfied: pint in /home/li/.local/lib/python3.9/site-packages (from gym-k8s-real==0.0.1) (0.19.2)
# Requirement already satisfied: pyyaml in /home/li/.local/lib/python3.9/site-packages (from gym-k8s-real==0.0.1) (6.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from gym-k8s-real==0.0.1) (2.25.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/li/.local/lib/python3.9/site-packages (from gym->gym-k8s-real==0.0.1) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/li/.local/lib/python3.9/site-packages (from gym->gym-k8s-real==0.0.1) (1.19.5)
# Installing collected packages: gym-k8s-real
#   Attempting uninstall: gym-k8s-real
#     Found existing installation: gym-k8s-real 0.0.1
#     Uninstalling gym-k8s-real-0.0.1:
#       Successfully uninstalled gym-k8s-real-0.0.1
#   Running setup.py develop for gym-k8s-real

# %%
import gym
import random
import subprocess
import time
import numpy as np
from threading import Lock, Thread
import datetime

# %%
import gym_k8s_real

# %% [markdown]
# ## Info about the kubernetes environment we deploy

# %%
# Timestep duration in minutes
# We wait these many minutes for our actions to be enforced
timestep_duration = 1.5
app_name = 'proxy'
memory_req = '128Mi'
cpu_req = '80m'
sla_throughput = 2.6
prometheus_host = 'http://145.100.135.52:30013'
# Nginx ingress latency metric
# prometheus_throughput_metric_name = '(sum(http_requests_total) by (app))'
prometheus_throughput_metric_name = 'latency'
gym_env = 'gym_k8s_real:k8s-env-discrete-state-discrete-action-v0'
q_table_file = 'Q-env-discrete-state-discrete-action-data.npy'
q_table_init_value = 12.5
total_epochs = 100
num_of_services = 1
steps_per_epoch = 20

# %% [markdown]
# ## Load or create the Q table
# If our Q table file is present, we load in into memory. Otherwise we create a gym environment and using the environment's observation and space dimensions, we create a new one.

# %%
try:
    q_table = np.load(q_table_file)
    print('File present. Loading done!')
    
except IOError:
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=prometheus_throughput_metric_name
    )

    q_table = np.full((env.observation_space.n, env.action_space.n), q_table_init_value)
    np.save(q_table_file, q_table)

    print('File not present. Created successfully!')

table_lock = Lock()
# Out:
# File not present. Created successfully!

# %%
q_table[409]
# Out:
# array([12.5, 12.5, 12.5])

# %% [markdown]
# ## Create historical states csv file if it doesn't exist

# %%
try:
    open('k8s_historical_states_discrete.csv', 'r').close()
    print('File already present.')
except IOError:
    with open('k8s_historical_states_discrete.csv', 'w') as f:
        f.write('current_app_name,timestep,state,action,next_state,reward,'
                'done,number_of_pods,cpu_util,latency_violation,latency,hpa_threshold,info\n')
    print('File not present. Created successfully!')
# Out:
# File not present. Created successfully!

# %% [markdown]
# # Train the agent

# %% [markdown]
# ## Agent training
# This function trains our agent:

# %%
def decode(i):
        out = []
        out.append(i % 7)
        i //= 7
        out.append(i % 5)
        i //= 5
        out.append(i % 5)
        i //= 5
        out.append(i)
        return reversed(out)

# %%
def train_agent(num_service):
    # Hyperparameters
    alpha = 0.1
    gamma = 0.9
    epsilon_init = 0.97
    epsilon_min = 0.2

    current_app_name = app_name
    current_throughput_metric_name = prometheus_throughput_metric_name
    
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=current_app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=current_throughput_metric_name
    )

    for epoch in range(0, total_epochs):
        state, _ = env.reset()
        decoded_state = list(decode(state))
        print('Training started with cpu utilization: {}, hpa cpu threshold: {}, number of pods: {}, latency:{}'
             .format(decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
     
        done = False
#         vegeta_process = stress_function(endpoint)

        for step in range(steps_per_epoch):
            current_timestep = epoch * steps_per_epoch + step
            q_table = np.load(q_table_file)
            
            # Epsilon keeps getting smaller and stops when it reaches epsilon_min
            current_epsilon = pow(epsilon_init, current_timestep)
            epsilon = max(current_epsilon, epsilon_min)
            
            if done:
                break
            else:    
                if random.uniform(0, 1) < epsilon:
                    action = env.action_space.sample()  # Explore action space, non-greedy (NG) action selection
                else:
                    action = np.argmax(q_table[state])  # Exploit learned values, greedy (G) action selection
                
                decoded_state = list(decode(state))
                print('======ROUND{}=======\n'
                      'app: {}, pod_cpu_util: {}, cpu_threshold: {}, number_of_pods: {}, latency: {}, latency_violation: {}, action: {}'
                      .format(step, current_app_name, decoded_state[0], decoded_state[1], decoded_state[2], 
                              decoded_state[3], int(decoded_state[3] > sla_throughput), action))
                
                real_ob, reward, done, next_state = env.step(action)
                
                now = datetime.datetime.now()
                dt_string = now.strftime('%d/%m/%Y %H:%M:%S')
                dt_dict = {
                    'datetime': dt_string
                }
                info = dt_dict

                (pod_cpu_util,
                 cpu_threshold,
                 number_of_pods,
                 throughput) = real_ob

                # Latency violation becomes 1 if the SLA was violated
                # otherwise it's 0
                throughput_violation = int(throughput > sla_throughput)
                

                # Save historical tuple
                with open('k8s_historical_states_discrete.csv', 'a') as f:
                    f.write(
                        '{},{},{},{},'.format(current_app_name, current_timestep, state, action) +
                        '{},{},{},{},'.format(next_state, reward, done, number_of_pods) +
                        '{},{},{},{},{}'.format(pod_cpu_util, throughput_violation, throughput, cpu_threshold, info) +
                        '\n'
                    )

                with table_lock:
                    old_value = q_table[state, action]
                    # Q-table update is always greedy (np.max)
                    # Q-learning is off-policy since the action taken can be of a different policy (non-greedy, random) (NG)
                    next_max = np.max(q_table[next_state])
                    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
                    q_table[state, action] = new_value
                    
                
                print('reward: {}, new_value: {}'.format(reward, new_value))
                
                print('new cpu utilization: {}, new hpa cpu threshold: {}, new number of pods: {}, new latency: {}, new latency_violation: {}'
                      .format(pod_cpu_util, cpu_threshold, number_of_pods, throughput, throughput_violation)
                      .format(decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
                
                state = next_state
                
                with table_lock:
                    np.save(q_table_file, q_table)

        with table_lock:
            np.save(q_table_file, q_table)

        print('Training finished.\n')

# %%
train_agent(num_of_services)
# Out:
# Created new namespaced_horizontal_pod_autoscaler
# Training started with cpu utilization: 2, hpa cpu threshold: 1, number of pods: 4, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.649910848859824, new_value: 13.439991084885982
# new cpu utilization: 57, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.5298740069071453, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 1
# reward: 8.683037877455096, new_value: 13.24330378774551
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.787082036336263, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 1, action: 1
# reward: 11.194502524142543, new_value: 13.494450252414254
# new cpu utilization: 31, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.1199324131011963, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.327568487324172, new_value: 13.707756848732418
# new cpu utilization: 106, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.4071118831634521, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.695930994091757, new_value: 13.844593099409176
# new cpu utilization: 106, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.3414289951324463, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 4, number_of_pods: 1, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.018250333292368, new_value: 13.676825033329237
# new cpu utilization: 104, new hpa cpu threshold: 100, new number of pods: 4, new latency: 1.4895331064860027, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 4, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 12.979019360532737, new_value: 13.672901936053274
# new cpu utilization: 80, new hpa cpu threshold: 100, new number of pods: 4, new latency: 1.5002723534901936, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 12.861033682885429, new_value: 13.661103368288543
# new cpu utilization: 76, new hpa cpu threshold: 100, new number of pods: 4, new latency: 1.5329771041870117, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 4, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.286802454890092, new_value: 13.50368024548901
# new cpu utilization: 85, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.6676696141560872, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 1, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.223916832731682, new_value: 13.497391683273168
# new cpu utilization: 61, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.376528263092041, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.741974527630823, new_value: 13.049197452763082
# new cpu utilization: 39, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.386142094930013, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.6645001050457315, new_value: 13.041450010504573
# new cpu utilization: 42, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4061757723490398, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.882957279129914, new_value: 12.963295727912993
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.622383753458659, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 1, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.867710764971315, new_value: 13.103467692009302
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.3541135787963867, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 1
# reward: 6.59075014797548, new_value: 13.075771630309717
# new cpu utilization: 43, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4254639148712158, new latency_violation: 0
# ======ROUND15=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.464049067169173, new_value: 13.490190508566485
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4591101010640461, new latency_violation: 0
# ======ROUND16=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.285092537279578, new_value: 13.983797857208778
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.507774035135905, new latency_violation: 0
# ======ROUND17=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 1
# reward: 6.127641850370317, new_value: 13.560270744596615
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5517497062683105, new latency_violation: 0
# ======ROUND18=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 1, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.469016143003377, new_value: 13.6985643442575
# new cpu utilization: 42, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4577786922454834, new latency_violation: 0
# ======ROUND19=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.187979234283364, new_value: 14.329215994916238
# new cpu utilization: 38, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5347654819488525, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# Training started with cpu utilization: 1, hpa cpu threshold: 0, number of pods: 4, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.5167199624599395, new_value: 13.191301435788455
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.445043643315633, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.41135661794673, new_value: 14.562430057219288
# new cpu utilization: 38, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.7672206560770671, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 1, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.562829626082022, new_value: 13.093500091829164
# new cpu utilization: 38, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4328224658966064, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.633511229535958, new_value: 13.66839320614638
# new cpu utilization: 42, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.6974833011627197, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 1, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.144520692015155, new_value: 14.17331536758644
# new cpu utilization: 39, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5469817320505779, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.049316751728258, new_value: 14.182083943787347
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5740484396616619, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 1, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.770159898154408, new_value: 14.743618525792973
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.3789108594258626, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 1
# reward: 6.487376343047298, new_value: 14.16360000959142
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4528661568959553, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.483871610001684, new_value: 15.03096176743839
# new cpu utilization: 38, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4538028240203857, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.0794283564487115, new_value: 12.882942835644872
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.87694255510966, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 1, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.404218265834814, new_value: 13.117347493904848
# new cpu utilization: 43, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.769508679707845, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 1, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.305999080476859, new_value: 15.252643140330816
# new cpu utilization: 43, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.502017895380656, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.818894070690316, new_value: 15.562541556833038
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.3664783636728923, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.248723083803661, new_value: 16.031788449645074
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5178333123524983, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.40015319520656, new_value: 16.345012479142085
# new cpu utilization: 36, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4763290087382, new latency_violation: 0
# ======ROUND15=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.734438126065469, new_value: 14.908370485137947
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.3880807558695476, new latency_violation: 0
# ======ROUND16=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.019682080818861, new_value: 16.88353056243255
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.316175937652588, new latency_violation: 0
# ======ROUND17=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.749848946400778, new_value: 17.295162400829373
# new cpu utilization: 14, new hpa cpu threshold: 20, new number of pods: 9, new latency: 0.9564424355824789, new latency_violation: 0
# ======ROUND18=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 1
# reward: 7.717741198295457, new_value: 13.36352746349196
# new cpu utilization: 28, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.151849349339803, new latency_violation: 0
# ======ROUND19=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.648746328041062, new_value: 15.407408069428259
# new cpu utilization: 25, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9544354279836019, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# Training started with cpu utilization: 1, hpa cpu threshold: 0, number of pods: 4, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.487391980253012, new_value: 13.868387750105688
# new cpu utilization: 38, new hpa cpu threshold: 40, new number of pods: 6, new latency: 1.3104406197865803, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 1
# reward: 10.867664496071802, new_value: 13.46176644960718
# new cpu utilization: 38, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.1935389041900635, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 1
# reward: 9.404026436389282, new_value: 14.26559164592513
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.2765992482503254, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.91400038619074, new_value: 14.479289355913554
# new cpu utilization: 50, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.208505392074585, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 1
# reward: 12.54481677688323, new_value: 14.298455086659283
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.32370392481486, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 12.221804212940611, new_value: 13.759041379093397
# new cpu utilization: 55, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.138511021931966, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 1
# reward: 12.274238772782423, new_value: 15.382894413070934
# new cpu utilization: 55, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.1268641948699951, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 1
# reward: 11.856639719476295, new_value: 16.414729440887854
# new cpu utilization: 54, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.2218674818674724, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 1
# reward: 11.998825036948801, new_value: 17.450464650173856
# new cpu utilization: 54, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.1889324982961018, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.038919666927795, new_value: 13.327622467638191
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.1053008238474529, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.33378272103235, new_value: 13.857350007805893
# new cpu utilization: 35, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.2403018474578857, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.294514136538321, new_value: 15.98278540238781
# new cpu utilization: 34, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.2496078809102376, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.374540685644698, new_value: 16.560411616928402
# new cpu utilization: 35, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.230695406595866, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.747480881351084, new_value: 17.169555588894227
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.1451829274495442, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.146428752716563, new_value: 17.712502908276942
# new cpu utilization: 37, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.2851582368214924, new latency_violation: 0
# ======ROUND15=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.052790459072057, new_value: 17.971531663356455
# new cpu utilization: 20, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.8752937316894531, new latency_violation: 0
# ======ROUND16=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.595834780945218, new_value: 13.234583478094521
# new cpu utilization: 23, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.965072234471639, new latency_violation: 0
# ======ROUND17=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception

# %%
with table_lock:
    np.save(q_table_file, q_table)

# %%
print(q_table[382])
# Out:
# [13.96471286 21.37426449 15.42381685]
