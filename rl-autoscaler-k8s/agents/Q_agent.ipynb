# %%
# !pip install -e ../gym_k8s_real
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/li/rl-autoscaler-k8s/gym_k8s_real
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym in /home/li/.local/lib/python3.9/site-packages (from gym-k8s-real==0.0.1) (0.21.0)
# Requirement already satisfied: pint in /home/li/.local/lib/python3.9/site-packages (from gym-k8s-real==0.0.1) (0.19.2)
# Requirement already satisfied: pyyaml in /home/li/.local/lib/python3.9/site-packages (from gym-k8s-real==0.0.1) (6.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from gym-k8s-real==0.0.1) (2.25.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/li/.local/lib/python3.9/site-packages (from gym->gym-k8s-real==0.0.1) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/li/.local/lib/python3.9/site-packages (from gym->gym-k8s-real==0.0.1) (1.19.5)
# Installing collected packages: gym-k8s-real
#   Attempting uninstall: gym-k8s-real
#     Found existing installation: gym-k8s-real 0.0.1
#     Uninstalling gym-k8s-real-0.0.1:
#       Successfully uninstalled gym-k8s-real-0.0.1
#   Running setup.py develop for gym-k8s-real
# Successfully installed gym-k8s-real
# WARNING: You are using pip version 22.0.4; however, version 22.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import gym
import random
import subprocess
import time
import numpy as np
from threading import Lock, Thread
import datetime

# %%
import gym_k8s_real

# %% [markdown]
# ## Info about the kubernetes environment we deploy

# %%
# Timestep duration in minutes
# We wait these many minutes for our actions to be enforced
timestep_duration = 1.5
app_name = 'proxy'
memory_req = '128Mi'
cpu_req = '80m'
sla_throughput = 2.6
prometheus_host = 'http://145.100.135.52:30013'
# Nginx ingress latency metric
# prometheus_throughput_metric_name = '(sum(http_requests_total) by (app))'
prometheus_throughput_metric_name = 'latency'
gym_env = 'gym_k8s_real:k8s-env-discrete-state-discrete-action-v0'
q_table_file = 'Q-env-discrete-state-discrete-action-data.npy'
q_table_init_value = 12.5
total_epochs = 100
num_of_services = 1
steps_per_epoch = 15

# %% [markdown]
# ## Load or create the Q table
# If our Q table file is present, we load in into memory. Otherwise we create a gym environment and using the environment's observation and space dimensions, we create a new one.

# %%
try:
    q_table = np.load(q_table_file)
    print('File present. Loading done!')
    
except IOError:
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=prometheus_throughput_metric_name
    )

    q_table = np.full((env.observation_space.n, env.action_space.n), q_table_init_value)
    np.save(q_table_file, q_table)

    print('File not present. Created successfully!')

table_lock = Lock()
# Out:
# File present. Loading done!

# %% [markdown]
# ## Create historical states csv file if it doesn't exist

# %%
try:
    open('k8s_historical_states_discrete.csv', 'r').close()
    print('File already present.')
except IOError:
    with open('k8s_historical_states_discrete.csv', 'w') as f:
        f.write('current_app_name,timestep,state,action,next_state,reward,'
                'done,number_of_pods,cpu_util,latency_violation,latency,hpa_threshold,info\n')
    print('File not present. Created successfully!')
# Out:
# File already present.

# %% [markdown]
# # Train the agent

# %% [markdown]
# ## Agent training
# This function trains our agent:

# %%
def decode(i):
        out = []
        out.append(i % 7)
        i //= 7
        out.append(i % 5)
        i //= 5
        out.append(i % 5)
        i //= 5
        out.append(i)
        return reversed(out)

# %%
def train_agent(num_service):
    # Hyperparameters
    alpha = 0.1
    gamma = 0.9
    epsilon_init = 0.97
    epsilon_min = 0.2

    current_app_name = app_name
    current_throughput_metric_name = prometheus_throughput_metric_name
    
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=current_app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=current_throughput_metric_name
    )

    for epoch in range(0, total_epochs):
        state, _ = env.reset()
        decoded_state = list(decode(state))
        print('======EPOCH{}=======\n'
              'Training started with cpu utilization: {}, hpa cpu threshold: {}, number of pods: {}, latency:{}'
             .format(epoch, decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
     
        done = False
#         vegeta_process = stress_function(ensdpoint)

        for step in range(steps_per_epoch):
            current_timestep = epoch * steps_per_epoch + step
            q_table = np.load(q_table_file)
            
            # Epsilon keeps getting smaller and stops when it reaches epsilon_min
            current_epsilon = pow(epsilon_init, current_timestep)
            epsilon = max(current_epsilon, epsilon_min)
            
            if done:
                break
            else:    
                if random.uniform(0, 1) < epsilon:
                    action = env.action_space.sample()  # Explore action space, non-greedy (NG) action selection
                else:
                    action = np.argmax(q_table[state])  # Exploit learned values, greedy (G) action selection
                
                decoded_state = list(decode(state))
                print('======ROUND{}=======\n'
                      'app: {}, pod_cpu_util: {}, cpu_threshold: {}, number_of_pods: {}, latency: {}, latency_violation: {}, action: {}'
                      .format(step, current_app_name, decoded_state[0], decoded_state[1], decoded_state[2], 
                              decoded_state[3], int(decoded_state[3] >= 5), action))
                
                real_ob, reward, done, next_state = env.step(action)
                
                now = datetime.datetime.now() + datetime.timedelta(hours=2)
                dt_string = now.strftime('%d/%m/%Y %H:%M:%S')
                dt_dict = {
                    'datetime': dt_string
                }
                info = dt_dict

                (pod_cpu_util,
                 cpu_threshold,
                 number_of_pods,
                 throughput) = real_ob

                # Latency violation becomes 1 if the SLA was violated
                # otherwise it's 0
                throughput_violation = int(throughput > sla_throughput)
                

                # Save historical tuple
                with open('k8s_historical_states_discrete.csv', 'a') as f:
                    f.write(
                        '{},{},{},{},'.format(current_app_name, current_timestep, state, action) +
                        '{},{},{},{},'.format(next_state, reward, done, number_of_pods) +
                        '{},{},{},{},{}'.format(pod_cpu_util, throughput_violation, throughput, cpu_threshold, info) +
                        '\n'
                    )

                with table_lock:
                    old_value = q_table[state, action]
                    # Q-table update is always greedy (np.max)
                    # Q-learning is off-policy since the action taken can be of a different policy (non-greedy, random) (NG)
                    next_max = np.max(q_table[next_state])
                    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
                    q_table[state, action] = new_value
                    
                
                print('reward: {}, new_value: {}'.format(reward, new_value))
                
                print('new cpu utilization: {}, new hpa cpu threshold: {}, new number of pods: {}, new latency: {}, new latency_violation: {}'
                      .format(pod_cpu_util, cpu_threshold, number_of_pods, throughput, throughput_violation)
                      .format(decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
                
                state = next_state
                
                with table_lock:
                    np.save(q_table_file, q_table)

        with table_lock:
            np.save(q_table_file, q_table)

        print('Training finished.\n')

# %%
train_agent(num_of_services)
# Out:
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH0=======
# Training started with cpu utilization: 0, hpa cpu threshold: 0, number of pods: 0, latency:1
# ======ROUND0=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 0, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 15.834861732875037, new_value: 13.958486173287504
# new cpu utilization: 80, new hpa cpu threshold: 60, new number of pods: 3, new latency: 1.0772640705108643, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 2, number_of_pods: 1, latency: 2, latency_violation: 0, action: 1
# reward: 13.10015313775055, new_value: 14.996324683647948
# new cpu utilization: 52, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.1911786397298176, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.76310913851531, new_value: 14.05131091385153
# new cpu utilization: 71, new hpa cpu threshold: 100, new number of pods: 3, new latency: 0.8882584571838379, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 4, number_of_pods: 1, latency: 1, latency_violation: 0, action: 1
# reward: 15.800776437765558, new_value: 13.955077643776555
# new cpu utilization: 75, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.0846124490102131, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 4, number_of_pods: 1, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 15.42998611107432, new_value: 13.917998611107432
# new cpu utilization: 91, new hpa cpu threshold: 80, new number of pods: 3, new latency: 1.1666302680969238, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 1, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.20081380487842, new_value: 14.401493444094033
# new cpu utilization: 56, new hpa cpu threshold: 60, new number of pods: 5, new latency: 0.9551346302032471, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 1
# reward: 17.38485354718047, new_value: 15.765841501943651
# new cpu utilization: 40, new hpa cpu threshold: 60, new number of pods: 2, new latency: 0.985328753789266, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.087302714578518, new_value: 13.783730271457852
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 5, new latency: 0.978043794631958, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.421008597848363, new_value: 13.65449184098268
# new cpu utilization: 24, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.0006890296936035, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.22875390577985, new_value: 19.383094572429307
# new cpu utilization: 48, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.1618822415669758, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.445238706776504, new_value: 27.021297616654593
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.0655101935068767, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.484650286826305, new_value: 17.72974401268131
# new cpu utilization: 24, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9876386324564616, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 0
# reward: 0, new_value: 13.946862716425999
# new cpu utilization: 24, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.1234570344289143, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 18.697474450259726
# new cpu utilization: 27, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.2693881193796794, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.784715438510158, new_value: 31.904015493609908
# new cpu utilization: 50, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.0406348705291748, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH1=======
# Training started with cpu utilization: 2, hpa cpu threshold: 2, number of pods: 2, latency:1
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.000157874892256, new_value: 19.936159924809083
# new cpu utilization: 36, new hpa cpu threshold: 40, new number of pods: 7, new latency: 0.9508160750071207, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.395399303850276, new_value: 14.014539930385027
# new cpu utilization: 73, new hpa cpu threshold: 80, new number of pods: 3, new latency: 0.9606845378875732, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 1
# reward: 16.7826864759329, new_value: 14.05326864759329
# new cpu utilization: 68, new hpa cpu threshold: 80, new number of pods: 3, new latency: 0.8844859600067139, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.985934869624622, new_value: 14.980510272461377
# new cpu utilization: 46, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.2176203727722168, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 14.516607762167183, new_value: 14.808883396316089
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.1224099000295003, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.283423283723806, new_value: 16.793794111278938
# new cpu utilization: 73, new hpa cpu threshold: 100, new number of pods: 3, new latency: 0.9833548069000244, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 4, number_of_pods: 1, latency: 1, latency_violation: 0, action: 1
# reward: 16.649318296273336, new_value: 15.480458696966124
# new cpu utilization: 75, new hpa cpu threshold: 100, new number of pods: 3, new latency: 0.9103496869405111, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 4, number_of_pods: 1, latency: 1, latency_violation: 0, action: 1
# reward: 16.496338527847875, new_value: 16.975287962781252
# new cpu utilization: 77, new hpa cpu threshold: 100, new number of pods: 3, new latency: 0.9404997825622559, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 4, number_of_pods: 1, latency: 1, latency_violation: 0, action: 1
# reward: 16.177905327245313, new_value: 18.020549699227658
# new cpu utilization: 86, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.004992405573527, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.01260635205729, new_value: 14.141245400083791
# new cpu utilization: 68, new hpa cpu threshold: 80, new number of pods: 3, new latency: 1.0394412676493328, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 15.467598313683146, new_value: 16.24086187338176
# new cpu utilization: 56, new hpa cpu threshold: 60, new number of pods: 4, new latency: 0.9242005348205566, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.732835047842007, new_value: 20.53785093837033
# new cpu utilization: 38, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.0051215489705403, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 11.695801484967683, new_value: 13.841603649754722
# new cpu utilization: 38, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.012780745824178, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.550016372541826, new_value: 15.61633349912223
# new cpu utilization: 66, new hpa cpu threshold: 80, new number of pods: 3, new latency: 0.9298608303070068, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 15.592165951668944, new_value: 16.890082424835462
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 4, new latency: 0.8998390833536783, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH2=======
# Training started with cpu utilization: 2, hpa cpu threshold: 2, number of pods: 2, latency:1
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 1
# reward: 13.962531822075151, new_value: 17.433917118410132
# new cpu utilization: 52, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.0035797754923503, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.088795184770243, new_value: 20.917945363010322
# new cpu utilization: 32, new hpa cpu threshold: 40, new number of pods: 5, new latency: 1.193790038426717, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 2, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.297095312942275, new_value: 14.39981694952942
# new cpu utilization: 75, new hpa cpu threshold: 80, new number of pods: 3, new latency: 0.9805708726247152, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.384711977666143, new_value: 18.971462165617446
# new cpu utilization: 45, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.1270054181416829, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.550783602185795, new_value: 26.848220296624945
# new cpu utilization: 30, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.0431030591328938, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 17.156236582083356, new_value: 16.917042040985
# new cpu utilization: 66, new hpa cpu threshold: 80, new number of pods: 2, new latency: 1.0326098601023357, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 15.030427799967724, new_value: 18.002433548711288
# new cpu utilization: 56, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.0125127633412678, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.328507632066565, new_value: 21.4810250911739
# new cpu utilization: 32, new hpa cpu threshold: 40, new number of pods: 7, new latency: 0.8863607247670492, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 11.420765971218433, new_value: 15.122053665589744
# new cpu utilization: 35, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.0707473754882812, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 15.619496544655577, new_value: 18.08342190132052
# new cpu utilization: 80, new hpa cpu threshold: 80, new number of pods: 3, new latency: 1.124226411183675, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 1, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.142012371613534, new_value: 16.79188516354223
# new cpu utilization: 53, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.2071623802185059, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 15.5780099969766, new_value: 16.81908831458779
# new cpu utilization: 55, new hpa cpu threshold: 60, new number of pods: 4, new latency: 0.9025903542836508, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.314859114301415, new_value: 22.191916464605498
# new cpu utilization: 38, new hpa cpu threshold: 40, new number of pods: 6, new latency: 1.1178950468699138, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.031230746333403, new_value: 19.498421805205822
# new cpu utilization: 71, new hpa cpu threshold: 80, new number of pods: 3, new latency: 1.0355254809061687, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 15.766177366939774, new_value: 19.776080412348634
# new cpu utilization: 55, new hpa cpu threshold: 60, new number of pods: 4, new latency: 0.866371234258016, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH3=======
# Training started with cpu utilization: 2, hpa cpu threshold: 2, number of pods: 2, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.924552920644842, new_value: 26.851530520168254
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.1805004278818767, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.66290063291652, new_value: 19.594421069129723
# new cpu utilization: 27, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.1642100016276042, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.736996995985491, new_value: 32.50395139066261
# new cpu utilization: 52, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.0507152080535889, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.536055773935814, new_value: 27.074841008013532
# new cpu utilization: 32, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.0462124347686768, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.75033958072136, new_value: 20.93104517766295
# new cpu utilization: 71, new hpa cpu threshold: 80, new number of pods: 3, new latency: 0.8907235463460287, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 2
# reward: 0, new_value: 12.95743159490557
# new cpu utilization: 71, new hpa cpu threshold: 80, new number of pods: 3, new latency: 0.8960055510203043, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.20173954067413, new_value: 20.601712523222485
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.1933682759602864, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 15.44280469843278, new_value: 23.741506670836987
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 4, new latency: 0.9290904998779297, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.287177258356543, new_value: 14.029731101310253
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 6, new latency: 0.9159873326619467, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.52473649319817, new_value: 14.75662777640984
# new cpu utilization: 68, new hpa cpu threshold: 80, new number of pods: 3, new latency: 0.9348631699879965, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.79367299204449, new_value: 22.4576442608259
# new cpu utilization: 45, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.0622864564259846, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.95942892764698, new_value: 27.226797696198553
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.1725552876790364, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.004496089996309, new_value: 21.36078419637602
# new cpu utilization: 26, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.0886144638061523, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 1
# reward: 8.844242384265472, new_value: 17.64071432166631
# new cpu utilization: 26, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9156914552052816, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.983381979591053, new_value: 20.840395794959978
# new cpu utilization: 50, new hpa cpu threshold: 60, new number of pods: 5, new latency: 0.9992862542470297, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH4=======
# Training started with cpu utilization: 2, hpa cpu threshold: 2, number of pods: 2, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.039982886387651, new_value: 27.591910281207127
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 6, new latency: 1.1795145670572917, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.305295392474136, new_value: 22.4896581826184
# new cpu utilization: 75, new hpa cpu threshold: 80, new number of pods: 3, new latency: 0.9789032936096191, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.69391256952387, new_value: 24.16454301700434
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.0836950937906902, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.276597425221912, new_value: 27.511392371083204
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 7, new latency: 0.8963925838470459, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.917254810625518, new_value: 18.22721486096816
# new cpu utilization: 23, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.1076098283131917, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.584192428644204, new_value: 33.08800080785826
# new cpu utilization: 44, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.0833947658538818, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.68585508925246, new_value: 27.95130922057397
# new cpu utilization: 45, new hpa cpu threshold: 40, new number of pods: 6, new latency: 1.0380563735961914, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.771218662834317, new_value: 21.977463264568247
# new cpu utilization: 28, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9300623734792074, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 1
# reward: 8.162958210950693, new_value: 15.044215893802313
# new cpu utilization: 28, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.0546355247497559, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.023335326625519, new_value: 33.17880674154948
# new cpu utilization: 53, new hpa cpu threshold: 60, new number of pods: 5, new latency: 0.9910885492960612, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 15.936425917737276, new_value: 14.096262466773396
# new cpu utilization: 77, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.0555509726206462, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 4, number_of_pods: 1, latency: 2, latency_violation: 0, action: 1
# reward: 16.75152980950103, new_value: 14.050152980950102
# new cpu utilization: 35, new hpa cpu threshold: 100, new number of pods: 3, new latency: 0.890493631362915, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 4, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 17.73658483167594, new_value: 14.148658483167594
# new cpu utilization: 106, new hpa cpu threshold: 80, new number of pods: 2, new latency: 0.9150147438049316, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 2
# reward: 0, new_value: 12.375
# new cpu utilization: 106, new hpa cpu threshold: 80, new number of pods: 2, new latency: 0.9238183498382568, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.391249523021422, new_value: 14.825860552677472
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.1503134568532307, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH5=======
# Training started with cpu utilization: 3, hpa cpu threshold: 2, number of pods: 2, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 14.731272836490708, new_value: 24.97721888777769
# new cpu utilization: 63, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.0756465593973796, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 15.259185989460066, new_value: 26.00268807976042
# new cpu utilization: 53, new hpa cpu threshold: 60, new number of pods: 4, new latency: 0.9657409191131592, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 1
# reward: 14.757455058472793, new_value: 19.681888742268058
# new cpu utilization: 56, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.070028305053711, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.8386555774536, new_value: 28.08049319374907
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 6, new latency: 1.006213665008545, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.363090460384111, new_value: 19.116438042456156
# new cpu utilization: 24, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.012651761372884, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.125515006226012, new_value: 22.166180197901078
# new cpu utilization: 42, new hpa cpu threshold: 60, new number of pods: 5, new latency: 0.9702978134155273, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.857820575899233, new_value: 22.580530376992826
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 7, new latency: 0.9795193672180176, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.799538401673619, new_value: 17.095145070557997
# new cpu utilization: 27, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9244749546051025, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.03945934795896, new_value: 22.478508112906866
# new cpu utilization: 38, new hpa cpu threshold: 60, new number of pods: 5, new latency: 0.9877911408742269, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 1
# reward: 14.74027078511317, new_value: 15.251271465948733
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.0737136999766033, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 15.62711465117512, new_value: 17.96256674736445
# new cpu utilization: 68, new hpa cpu threshold: 60, new number of pods: 4, new latency: 0.8930652936299642, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.18367825572797, new_value: 15.56560524057308
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 7, new latency: 0.9144958655039469, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.631817736323979, new_value: 20.954068618582394
# new cpu utilization: 30, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.1712551911671956, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.050968991373475, new_value: 33.6932673539693
# new cpu utilization: 45, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.202515443166097, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.879532437302615, new_value: 28.43836881191557
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 6, new latency: 1.2165222962697346, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH6=======
# Training started with cpu utilization: 2, hpa cpu threshold: 1, number of pods: 3, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.016227886410052, new_value: 23.613733788609665
# new cpu utilization: 30, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.0860758622487385, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.48848076292958, new_value: 34.232241887937725
# new cpu utilization: 50, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.104182481765747, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.176369262117401, new_value: 28.79803503260817
# new cpu utilization: 44, new hpa cpu threshold: 40, new number of pods: 6, new latency: 0.9378449122111002, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.748232128098042, new_value: 21.756550699695577
# new cpu utilization: 24, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9346108436584473, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.098483231747576, new_value: 24.132328777725675
# new cpu utilization: 45, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.191562334696452, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.298261546109192, new_value: 29.206147246930875
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 6, new latency: 0.913815975189209, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.550580460801802, new_value: 22.60786326580151
# new cpu utilization: 26, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9742217858632406, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.611480738826605, new_value: 25.708797226059545
# new cpu utilization: 45, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.0775133768717449, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.333857571498982, new_value: 29.157481335737906
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 6, new latency: 0.9068612257639567, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.61972051680285, new_value: 17.672602615182484
# new cpu utilization: 19, new hpa cpu threshold: 20, new number of pods: 7, new latency: 1.0286226272583008, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 19, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9982445240020752, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 19, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9333212375640869, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 11.959584550790339, new_value: 13.570958455079033
# new cpu utilization: 19, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9589496453603109, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 11.02215158186247, new_value: 14.441077767757378
# new cpu utilization: 19, new hpa cpu threshold: 20, new number of pods: 8, new latency: 0.9243979454040527, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 19, new hpa cpu threshold: 20, new number of pods: 8, new latency: 0.9202225208282471, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH7=======
# Training started with cpu utilization: 0, hpa cpu threshold: 0, number of pods: 4, latency:1
# ======ROUND0=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 1
# reward: 12.34337591372863, new_value: 13.784034590471027
# new cpu utilization: 19, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.8834980328877767, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 12.258097259258985, new_value: 15.522476716005702
# new cpu utilization: 18, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.8999818960825602, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 12.04439851659684, new_value: 16.299668896064816
# new cpu utilization: 20, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9419906139373779, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 20, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9713739554087321, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 12.30941155988125, new_value: 13.605941155988125
# new cpu utilization: 20, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.890044371287028, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 11.806801255992067, new_value: 14.892997366634352
# new cpu utilization: 19, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9899245897928873, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 12.243692442378942, new_value: 17.23444101369332
# new cpu utilization: 20, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9027818044026693, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 11.750648527546607, new_value: 16.129862173957978
# new cpu utilization: 19, new hpa cpu threshold: 20, new number of pods: 7, new latency: 1.001449426015218, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 10.086541168656517, new_value: 17.760214142332032
# new cpu utilization: 14, new hpa cpu threshold: 20, new number of pods: 9, new latency: 0.8901695410410563, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 1
# reward: 11.755177108934618, new_value: 15.032836437973604
# new cpu utilization: 21, new hpa cpu threshold: 20, new number of pods: 7, new latency: 1.0005171298980713, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 12.138179997890619, new_value: 17.182381552007463
# new cpu utilization: 21, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9234296480814616, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 11.912932459402267, new_value: 18.201850982427615
# new cpu utilization: 20, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9683492183685303, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 12.156608775885068, new_value: 19.23549335019185
# new cpu utilization: 20, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9198055267333984, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 12.135901003734313, new_value: 20.25672851706336
# new cpu utilization: 20, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9238783518473307, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 12.062046682584025, new_value: 21.260365900151132
# new cpu utilization: 20, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9384825229644775, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH8=======
# Training started with cpu utilization: 1, hpa cpu threshold: 0, number of pods: 3, latency:1
# ======ROUND0=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 12.190263769239344, new_value: 21.951774959869837
# new cpu utilization: 18, new hpa cpu threshold: 20, new number of pods: 7, new latency: 0.9132065773010254, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 3, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 17.40779785748403, new_value: 14.115779785748403
# new cpu utilization: 73, new hpa cpu threshold: 60, new number of pods: 2, new latency: 0.9806540012359619, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.062231455090549, new_value: 13.781223145509054
# new cpu utilization: 36, new hpa cpu threshold: 40, new number of pods: 5, new latency: 0.9831448396046957, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 train_agent(num_of_services)
#
# Input In [9], in train_agent(num_service)
#      46 decoded_state = list(decode(state))
#      47 print('======ROUND{}=======\n'
#      48       'app: {}, pod_cpu_util: {}, cpu_threshold: {}, number_of_pods: {}, latency: {}, latency_violation: {}, action: {}'
#      49       .format(step, current_app_name, decoded_state[0], decoded_state[1], decoded_state[2],
#      50               decoded_state[3], int(decoded_state[3] >= 5), action))
# ---> 52 real_ob, reward, done, next_state = env.step(action)
#      54 now = datetime.datetime.now() + datetime.timedelta(hours=2)
#      55 dt_string = now.strftime('%d/%m/%Y %H:%M:%S')
#
# File ~/.local/lib/python3.9/site-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       9 def step(self, action):
#      10     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11     observation, reward, done, info = self.env.step(action)
#      12     return observation, reward, done, info
#
# File ~/rl-autoscaler-k8s/gym_k8s_real/gym_k8s_real/envs/k8s_env_discrete_state_discrete_action.py:95, in K8sEnvDiscreteStateDiscreteAction.step(self, action)
#      93 self._take_action(action)  # Create HPA
#      94 wait_time = self.timestep_duration * 60
# ---> 95 time.sleep(wait_time)  # Wait timestep_duration minutes for the changes to take place
#      97 encoded_observation, real_observation = self._get_state()
#      98 reward = self._get_reward(real_observation)
#
# KeyboardInterrupt:

# %%
with table_lock:
    np.save(q_table_file, q_table)

# %%
print(q_table[382])
# Out:
# [13.96471286 21.37426449 15.42381685]
