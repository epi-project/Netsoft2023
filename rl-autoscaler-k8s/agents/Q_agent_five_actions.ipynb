# %%
# !pip install -e ../gym_k8s_real
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/li/rl-autoscaler-k8s/gym_k8s_real
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym in /home/li/.local/lib/python3.9/site-packages (from gym-k8s-real==0.0.1) (0.21.0)
# Requirement already satisfied: pint in /home/li/.local/lib/python3.9/site-packages (from gym-k8s-real==0.0.1) (0.19.2)
# Requirement already satisfied: pyyaml in /home/li/.local/lib/python3.9/site-packages (from gym-k8s-real==0.0.1) (6.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from gym-k8s-real==0.0.1) (2.25.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/li/.local/lib/python3.9/site-packages (from gym->gym-k8s-real==0.0.1) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/li/.local/lib/python3.9/site-packages (from gym->gym-k8s-real==0.0.1) (1.19.5)
# Installing collected packages: gym-k8s-real
#   Attempting uninstall: gym-k8s-real
#     Found existing installation: gym-k8s-real 0.0.1
#     Uninstalling gym-k8s-real-0.0.1:
#       Successfully uninstalled gym-k8s-real-0.0.1
#   Running setup.py develop for gym-k8s-real
# Successfully installed gym-k8s-real
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import gym
import random
import subprocess
import time
import numpy as np
from threading import Lock, Thread
import datetime

# %%
import gym_k8s_real

# %% [markdown]
# ## Info about the kubernetes environment we deploy

# %%
# Timestep duration in minutes
# We wait these many minutes for our actions to be enforced
timestep_duration = 1.5
app_name = 'proxy'
memory_req = '128Mi'
cpu_req = '80m'
sla_throughput = 2.6
prometheus_host = 'http://145.100.135.52:30013'
# Nginx ingress latency metric
# prometheus_throughput_metric_name = '(sum(http_requests_total) by (app))'
prometheus_throughput_metric_name = 'latency'
gym_env = 'gym_k8s_real:k8s-env-discrete-state-five-action-v0'
q_table_file = 'Q-env-discrete-state-discrete-five-action-data.npy'
q_table_init_value = 12.5
total_epochs = 100
num_of_services = 1
steps_per_epoch = 15

# %% [markdown]
# ## Load or create the Q table
# If our Q table file is present, we load in into memory. Otherwise we create a gym environment and using the environment's observation and space dimensions, we create a new one.

# %%
try:
    q_table = np.load(q_table_file)
    print('File present. Loading done!')
    
except IOError:
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=prometheus_throughput_metric_name
    )

    q_table = np.full((env.observation_space.n, env.action_space.n), q_table_init_value)
    np.save(q_table_file, q_table)

    print('File not present. Created successfully!')

table_lock = Lock()
# Out:
# File not present. Created successfully!

# %% [markdown]
# ## Create historical states csv file if it doesn't exist

# %%
try:
    open('k8s_historical_discrete_states_five_actions.csv', 'r').close()
    print('File already present.')
except IOError:
    with open('k8s_historical_discrete_states_five_actions.csv', 'w') as f:
        f.write('current_app_name,timestep,state,action,next_state,reward,'
                'done,number_of_pods,cpu_util,latency_violation,latency,hpa_threshold,info\n')
    print('File not present. Created successfully!')
# Out:
# File already present.

# %% [markdown]
# # Train the agent

# %% [markdown]
# ## Agent training
# This function trains our agent:

# %%
def decode(i):
        out = []
        out.append(i % 7)
        i //= 7
        out.append(i % 5)
        i //= 5
        out.append(i % 5)
        i //= 5
        out.append(i)
        return reversed(out)

# %%
def train_agent(num_service):
    # Hyperparameters
    alpha = 0.1
    gamma = 0.9
    epsilon_init = 0.97
    epsilon_min = 0.2

    current_app_name = app_name
    current_throughput_metric_name = prometheus_throughput_metric_name
    
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=current_app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=current_throughput_metric_name
    )

    for epoch in range(0, total_epochs):
        state, _ = env.reset()
        decoded_state = list(decode(state))
        print('======EPOCH{}=======\n'
              'Training started with cpu utilization: {}, hpa cpu threshold: {}, number of pods: {}, latency:{}'
             .format(epoch, decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
     
        done = False
#         vegeta_process = stress_function(ensdpoint)

        for step in range(steps_per_epoch):
            current_timestep = epoch * steps_per_epoch + step
            q_table = np.load(q_table_file)
            
            # Epsilon keeps getting smaller and stops when it reaches epsilon_min
            current_epsilon = pow(epsilon_init, current_timestep)
            epsilon = max(current_epsilon, epsilon_min)
            
            if done:
                break
            else:    
                if random.uniform(0, 1) < epsilon:
                    action = env.action_space.sample()  # Explore action space, non-greedy (NG) action selection
                else:
                    action = np.argmax(q_table[state])  # Exploit learned values, greedy (G) action selection
                
                decoded_state = list(decode(state))
                print('======ROUND{}=======\n'
                      'app: {}, pod_cpu_util: {}, cpu_threshold: {}, number_of_pods: {}, latency: {}, latency_violation: {}, action: {}'
                      .format(step, current_app_name, decoded_state[0], decoded_state[1], decoded_state[2], 
                              decoded_state[3], int(decoded_state[3] >= 5), action))
                
                real_ob, reward, done, next_state = env.step(action)
                
                now = datetime.datetime.now() + datetime.timedelta(hours=2)
                dt_string = now.strftime('%d/%m/%Y %H:%M:%S')
                dt_dict = {
                    'datetime': dt_string
                }
                info = dt_dict

                (pod_cpu_util,
                 cpu_threshold,
                 number_of_pods,
                 throughput) = real_ob

                # Latency violation becomes 1 if the SLA was violated
                # otherwise it's 0
                throughput_violation = int(throughput > sla_throughput)
                

                # Save historical tuple
                with open('k8s_historical_discrete_states_five_actions.csv', 'a') as f:
                    f.write(
                        '{},{},{},{},'.format(current_app_name, current_timestep, state, action) +
                        '{},{},{},{},'.format(next_state, reward, done, number_of_pods) +
                        '{},{},{},{},{}'.format(pod_cpu_util, throughput_violation, throughput, cpu_threshold, info) +
                        '\n'
                    )

                with table_lock:
                    old_value = q_table[state, action]
                    # Q-table update is always greedy (np.max)
                    # Q-learning is off-policy since the action taken can be of a different policy (non-greedy, random) (NG)
                    next_max = np.max(q_table[next_state])
                    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
                    q_table[state, action] = new_value
                    
                
                print('reward: {}, new_value: {}'.format(reward, new_value))
                
                print('new cpu utilization: {}, new hpa cpu threshold: {}, new number of pods: {}, new latency: {}, new latency_violation: {}'
                      .format(pod_cpu_util, cpu_threshold, number_of_pods, throughput, throughput_violation)
                      .format(decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
                
                state = next_state
                
                with table_lock:
                    np.save(q_table_file, q_table)

        with table_lock:
            np.save(q_table_file, q_table)

        print('Training finished.\n')

# %%
train_agent(num_of_services)
# Out:
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH0=======
# Training started with cpu utilization: 0, hpa cpu threshold: 0, number of pods: 0, latency:1
# ======ROUND0=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 0, latency: 1, latency_violation: 0, action: 1
# reward: 0, new_value: 12.375
# new cpu utilization: 0, new hpa cpu threshold: 20, new number of pods: 1, new latency: 0.9118185838063558, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 0, latency: 1, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.02196482996812, new_value: 13.377196482996812
# new cpu utilization: 133, new hpa cpu threshold: 40, new number of pods: 4, new latency: 2.2089010874430337, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 1, number_of_pods: 2, latency: 4, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.398192563903438, new_value: 13.114819256390344
# new cpu utilization: 68, new hpa cpu threshold: 80, new number of pods: 6, new latency: 2.429841677347819, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 3, latency: 4, latency_violation: 0, action: 2
# reward: 8.626611079398906, new_value: 13.237661107939891
# new cpu utilization: 70, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.3623345692952475, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 2
# reward: 8.810255346777854, new_value: 13.256025534677786
# new cpu utilization: 78, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.261664787928263, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 2
# reward: 7.686218996532433, new_value: 13.89043438057784
# new cpu utilization: 78, new hpa cpu threshold: 80, new number of pods: 6, new latency: 2.2685619990030923, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 3, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.445963357128717, new_value: 12.919596335712871
# new cpu utilization: 51, new hpa cpu threshold: 60, new number of pods: 8, new latency: 2.278231143951416, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 4, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.199085512223042, new_value: 12.694908551222305
# new cpu utilization: 47, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.291538874308268, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# reward: 0, new_value: 12.375
# new cpu utilization: 47, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.3144816557566323, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# reward: 0, new_value: 12.262500000000001
# new cpu utilization: 46, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.255274852116903, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.1006245143437403, new_value: 12.685062451434375
# new cpu utilization: 46, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.3457253774007163, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 46, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.3933125336964927, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.4702527875349114, new_value: 12.738680899382585
# new cpu utilization: 45, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.150510629018148, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 2.927825991907173, new_value: 12.855820086426089
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.4451205730438232, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.1609646801088567, new_value: 12.93793308523356
# new cpu utilization: 45, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.3123176097869873, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH1=======
# Training started with cpu utilization: 2, hpa cpu threshold: 0, number of pods: 4, latency:4
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# reward: 0, new_value: 12.193273807778349
# new cpu utilization: 47, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.2614729404449463, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.184803845312659, new_value: 13.053132439985767
# new cpu utilization: 45, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.2992943127950034, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.086829002225133, new_value: 13.477822676932718
# new cpu utilization: 46, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9128923416137695, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.422032154229544, new_value: 13.417203215422955
# new cpu utilization: 21, new hpa cpu threshold: 40, new number of pods: 5, new latency: 1.5643965403238933, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 62, new hpa cpu threshold: 40, new number of pods: 5, new latency: 1.3439452648162842, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 1, number_of_pods: 2, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.837488641402633, new_value: 13.558748864140263
# new cpu utilization: 83, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.4592499732971191, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.418061548108896, new_value: 13.01680615481089
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.4142080942789714, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.6869866053263347, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 6.724213331851527, new_value: 13.047421333185152
# new cpu utilization: 39, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.3169920444488525, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 5.313676585529188, new_value: 12.955635578539583
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.818633238474528, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 5.523377665359534, new_value: 13.461024168471154
# new cpu utilization: 39, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.34492293993632, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 5.5939362772950405, new_value: 13.34446564841513
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.3229206403096516, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.069077970909397, new_value: 13.381907797090939
# new cpu utilization: 69, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.6949032147725422, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 4
# reward: 0, new_value: 12.375
# new cpu utilization: 69, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.632682164510091, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.568547045570435, new_value: 12.918346879719447
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.67389980951945, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH2=======
# Training started with cpu utilization: 2, hpa cpu threshold: 1, number of pods: 4, latency:3
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.236792845918313, new_value: 13.750093211378275
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.8045734564463298, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.3082422551328605, new_value: 14.043416504777777
# new cpu utilization: 48, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.775586207707723, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 6.405654959746232, new_value: 14.480642258631985
# new cpu utilization: 38, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.4182650248209636, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 6.69754472851604, new_value: 13.884145258163406
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.3252469698588054, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.03533675044298, new_value: 14.309901911600894
# new cpu utilization: 68, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.7514432271321614, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.744553857490308, new_value: 13.404225380773413
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.6083760261535645, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.274594634583872, new_value: 14.763295299504051
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.7891767819722493, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 5.466260770491219, new_value: 15.083164919837476
# new cpu utilization: 38, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.3629405498504639, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 5.444038145935599, new_value: 14.328025718984705
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.3700016339619954, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.884956456347563, new_value: 14.992407366075561
# new cpu utilization: 53, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.7670942942301433, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.086413352795656, new_value: 13.207957998226366
# new cpu utilization: 49, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.526062250137329, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.687428120626084, new_value: 15.833421995463594
# new cpu utilization: 80, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.5102967421213787, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.152794766532521, new_value: 13.490279476653253
# new cpu utilization: 83, new hpa cpu threshold: 100, new number of pods: 4, new latency: 1.7054555416107178, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.223911084199434, new_value: 13.297391108419944
# new cpu utilization: 66, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.5956679979960124, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.041608486635545, new_value: 12.779160848663555
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.8863240877787273, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH3=======
# Training started with cpu utilization: 2, hpa cpu threshold: 0, number of pods: 4, latency:3
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5563313961029053, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 1
# reward: 0, new_value: 12.375
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.691678762435913, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.632602995104991, new_value: 12.838260299510498
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.649765412012736, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 1
# reward: 0, new_value: 12.292943426955945
# new cpu utilization: 46, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.7304558753967285, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.649660379823762, new_value: 13.17484373449777
# new cpu utilization: 42, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.643394947052002, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.264435485115128, new_value: 13.408802909559506
# new cpu utilization: 38, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.7933011849721272, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 38, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5203859011332195, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.293808257782793, new_value: 13.20438082577828
# new cpu utilization: 52, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.5312356154123943, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.821853184183886, new_value: 12.938977580278744
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5803637504577637, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.965753346027026, new_value: 13.689497953206258
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.529392162958781, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5346756776173909, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 1
# reward: 0, new_value: 12.482054815788564
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.721254587173462, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.453606785243684, new_value: 13.89090883641
# new cpu utilization: 39, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.7180667718251545, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 1
# reward: 0, new_value: 12.375
# new cpu utilization: 39, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.6748917897542317, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.449606124592676, new_value: 12.945142407736167
# new cpu utilization: 42, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.7196245193481445, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH4=======
# Training started with cpu utilization: 2, hpa cpu threshold: 0, number of pods: 4, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 3.75023557579136, new_value: 12.875205352856035
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.0160191853841147, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.741683461881325, new_value: 14.141049115653388
# new cpu utilization: 38, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.6094249884287517, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.876702063315607, new_value: 13.410992793702917
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5607582728068035, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 5.0735043273920075, new_value: 14.393063118584294
# new cpu utilization: 45, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4921831289927165, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 4.956246183103028, new_value: 13.24207791763778
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5327138900756836, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 4.311704599098693, new_value: 13.644416266456458
# new cpu utilization: 43, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.7741937637329102, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 4.261958925555351, new_value: 14.675328379953987
# new cpu utilization: 45, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.794308106104533, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 7.254960224857699, new_value: 15.140839853832425
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.8722501595815023, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 0
# reward: 0, new_value: 12.457548289388066
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.92324431737264, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.460621092706585, new_value: 14.346545003151318
# new cpu utilization: 21, new hpa cpu threshold: 40, new number of pods: 5, new latency: 1.2290999094645183, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 56, new hpa cpu threshold: 40, new number of pods: 5, new latency: 1.2000865936279297, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 2, latency: 2, latency_violation: 0, action: 2
# reward: 6.104032009770045, new_value: 13.285411180568728
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.5199349721272786, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.965803215431173, new_value: 16.57166011746035
# new cpu utilization: 70, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.416762113571167, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.910851392492841, new_value: 13.298569982034657
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.6289284229278564, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# reward: 5.345639838319564, new_value: 15.600861822257116
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.4016173680623372, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH5=======
# Training started with cpu utilization: 2, hpa cpu threshold: 1, number of pods: 4, latency:3
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 0
# reward: 0, new_value: 12.741449410571432
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.3682018121083577, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.319601371684403, new_value: 17.243325541265875
# new cpu utilization: 66, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.2709961732228596, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.549433997229643, new_value: 14.175555682268085
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.3718222777048747, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.205997218383487, new_value: 18.015392720381765
# new cpu utilization: 71, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.3399238586425781, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 2
# reward: 12.557704233156539, new_value: 13.781570434719782
# new cpu utilization: 75, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.233222484588623, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.838846993779262, new_value: 15.163270158253562
# new cpu utilization: 45, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.3159046173095703, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.562982778117874, new_value: 18.834846040398197
# new cpu utilization: 73, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.2316700617472331, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 4
# reward: 0, new_value: 12.61469431424282
# new cpu utilization: 73, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.2657697995503743, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.961354453539935, new_value: 16.13821473141804
# new cpu utilization: 46, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.2785042921702068, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.795253303953167, new_value: 19.255886766753697
# new cpu utilization: 53, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.4734659989674885, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.916450712199634, new_value: 13.266645071219964
# new cpu utilization: 46, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.3262762228647869, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.983029809007833
# new cpu utilization: 45, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.1576050122578938, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.585148247360252, new_value: 20.041252240641978
# new cpu utilization: 66, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.2251663208007812, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.097588927492517, new_value: 13.784758892749252
# new cpu utilization: 88, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.1114433606465657, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 2, latency_violation: 0, action: 3
# reward: 0, new_value: 12.375
# new cpu utilization: 88, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.1990680694580078, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH6=======
# Training started with cpu utilization: 4, hpa cpu threshold: 4, number of pods: 1, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.041926661742686, new_value: 13.479192666174269
# new cpu utilization: 56, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.35657533009847, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.072905223856215, new_value: 13.045684796705666
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.1805205345153809, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.438394274320045
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.129205624262492, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.626947678922349, new_value: 14.120749142796196
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.4929049015045166, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.829451290877921, new_value: 13.59492886897455
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.2514385382334392, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.804428244822251, new_value: 15.112660651206511
# new cpu utilization: 48, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.1310096581776936, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.867589224079397, new_value: 14.182334363093622
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.2401355107625325, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.835128180903693, new_value: 15.849415386401317
# new cpu utilization: 46, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.0921133359273274, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.777538538503452, new_value: 13.649281060877334
# new cpu utilization: 28, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.2669434547424316, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.99985336945945, new_value: 16.740869277385556
# new cpu utilization: 56, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.0776323477427165, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.269676270840622, new_value: 14.797746788833022
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4264253775278728, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.69164360339424, new_value: 17.4677439209814
# new cpu utilization: 57, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.4709325631459553, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.393620920386129, new_value: 15.429431154876658
# new cpu utilization: 36, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.386128822962443, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 5.491252313254615, new_value: 13.371222184213789
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.3550338745117188, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.535994198505906, new_value: 13.293121734559215
# new cpu utilization: 39, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.411981503168742, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH7=======
# Training started with cpu utilization: 1, hpa cpu threshold: 1, number of pods: 4, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 8.156016112652324, new_value: 15.000347073060091
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.2206876277923584, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.600031236575408
# new cpu utilization: 35, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.3533322016398113, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 8.601477329488977, new_value: 16.16417280036076
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.095215876897176, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.343330924198936, new_value: 20.7238994348253
# new cpu utilization: 71, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.2974743048350017, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.525581990483389, new_value: 16.731727009357044
# new cpu utilization: 31, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.0856735706329346, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 8.404128967851094, new_value: 17.25331936624407
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.1496851444244385, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 8.46449522369377, new_value: 13.649248265331344
# new cpu utilization: 38, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.1328412691752117, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# reward: 9.297340827874553, new_value: 17.626194195217824
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.2118842601776123, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.853199510917756
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.2849044799804688, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.724667515808578
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.0487643082936604, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.597420840650493
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.4940991401672363, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.471446632243987
# new cpu utilization: 45, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.2366832892100017, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.582977101173977, new_value: 13.380394663005724
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.3263197739919026, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.24850919290878, new_value: 18.234469252113037
# new cpu utilization: 49, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.292507568995158, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.822887415651774, new_value: 16.109879013644345
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.2533913453420003, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH8=======
# Training started with cpu utilization: 1, hpa cpu threshold: 0, number of pods: 4, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.478684113158913, new_value: 19.008779849445617
# new cpu utilization: 53, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.2238059043884277, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.534653809242349, new_value: 16.863146679654253
# new cpu utilization: 31, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.0534979502360027, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# reward: 0, new_value: 12.905345033338147
# new cpu utilization: 31, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.1630602677663167, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.333206837145923, new_value: 19.369657843694608
# new cpu utilization: 50, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.2338920434315999, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.398920307623013, new_value: 14.667514191484416
# new cpu utilization: 32, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.0898807843526204, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 train_agent(num_of_services)
#
# Input In [8], in train_agent(num_service)
#      46 decoded_state = list(decode(state))
#      47 print('======ROUND{}=======\n'
#      48       'app: {}, pod_cpu_util: {}, cpu_threshold: {}, number_of_pods: {}, latency: {}, latency_violation: {}, action: {}'
#      49       .format(step, current_app_name, decoded_state[0], decoded_state[1], decoded_state[2],
#      50               decoded_state[3], int(decoded_state[3] >= 5), action))
# ---> 52 real_ob, reward, done, next_state = env.step(action)
#      54 now = datetime.datetime.now() + datetime.timedelta(hours=2)
#      55 dt_string = now.strftime('%d/%m/%Y %H:%M:%S')
#
# File ~/.local/lib/python3.9/site-packages/gym/wrappers/order_enforcing.py:11, in OrderEnforcing.step(self, action)
#       9 def step(self, action):
#      10     assert self._has_reset, "Cannot call env.step() before calling reset()"
# ---> 11     observation, reward, done, info = self.env.step(action)
#      12     return observation, reward, done, info
#
# File ~/rl-autoscaler-k8s/gym_k8s_real/gym_k8s_real/envs/k8s_env_discrete_state_five_action.py:99, in K8sEnvDiscreteStateFiveAction.step(self, action)
#      97 self._take_action(action)  # Create HPA
#      98 wait_time = self.timestep_duration * 60
# ---> 99 time.sleep(wait_time)  # Wait timestep_duration minutes for the changes to take place
#     101 encoded_observation, real_observation = self._get_state()
#     102 reward = self._get_reward(real_observation)
#
# KeyboardInterrupt:

# %%
with table_lock:
    np.save(q_table_file, q_table)

# %%
print(q_table[382])
# Out:
# [13.96471286 21.37426449 15.42381685]
