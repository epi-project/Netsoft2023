# %%
# !pip install -e ../gym_k8s_real

# %%
import gym
import random
import subprocess
import time
import numpy as np
from threading import Lock, Thread
import datetime

# %%
import gym_k8s_real

# %% [markdown]
# ## Info about the kubernetes environment we deploy

# %%
# Timestep duration in minutes
# We wait these many minutes for our actions to be enforced
timestep_duration = 1.5
app_name = 'proxy'
memory_req = '128Mi'
cpu_req = '80m'
sla_throughput = 2.6
prometheus_host = 'http://145.100.135.52:30013'
# Nginx ingress latency metric
# prometheus_throughput_metric_name = '(sum(http_requests_total) by (app))'
prometheus_throughput_metric_name = 'latency'
gym_env = 'gym_k8s_real:k8s-env-discrete-state-discrete-action-v1'
q_table_file = 'Q-env-discrete-state-discrete-action-data-V1.npy'
q_table_init_value = 12.5
total_epochs = 100
num_of_services = 1
steps_per_epoch = 15

# %% [markdown]
# ## Load or create the Q table
# If our Q table file is present, we load in into memory. Otherwise we create a gym environment and using the environment's observation and space dimensions, we create a new one.

# %%
try:
    q_table = np.load(q_table_file)
    print('File present. Loading done!')
    
except IOError:
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=prometheus_throughput_metric_name
    )

    q_table = np.full((env.observation_space.n, env.action_space.n), q_table_init_value)
    np.save(q_table_file, q_table)

    print('File not present. Created successfully!')

table_lock = Lock()
# Out:
# File not present. Created successfully!

# %% [markdown]
# ## Create historical states csv file if it doesn't exist

# %%
try:
    open('k8s_historical_states_discrete_V1.csv', 'r').close()
    print('File already present.')
except IOError:
    with open('k8s_historical_states_discrete_V1.csv', 'w') as f:
        f.write('current_app_name,timestep,state,action,next_state,reward,'
                'done,number_of_pods,cpu_util,latency_violation,latency,hpa_threshold,info\n')
    print('File not present. Created successfully!')
# Out:
# File not present. Created successfully!

# %% [markdown]
# # Train the agent

# %% [markdown]
# ## Agent training
# This function trains our agent:

# %%
def decode(i):
        out = []
        out.append(i % 7)
        i //= 7
        out.append(i % 5)
        i //= 5
        out.append(i % 5)
        i //= 5
        out.append(i)
        return reversed(out)

# %%
def train_agent(num_service):
    # Hyperparameters
    alpha = 0.1
    gamma = 0.9
    epsilon_init = 0.97
    epsilon_min = 0.2

    current_app_name = app_name
    current_throughput_metric_name = prometheus_throughput_metric_name
    
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=current_app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=current_throughput_metric_name
    )

    for epoch in range(0, total_epochs):
        state, _ = env.reset()
        decoded_state = list(decode(state))
        print('======EPOCH{}=======\n'
              'Training started with cpu utilization: {}, hpa cpu threshold: {}, number of pods: {}, latency:{}'
             .format(epoch, decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
     
        done = False
#         vegeta_process = stress_function(ensdpoint)

        for step in range(steps_per_epoch):
            current_timestep = epoch * steps_per_epoch + step
            q_table = np.load(q_table_file)
            
            # Epsilon keeps getting smaller and stops when it reaches epsilon_min
            current_epsilon = pow(epsilon_init, current_timestep)
            epsilon = max(current_epsilon, epsilon_min)
            
            if done:
                break
            else:    
                if random.uniform(0, 1) < epsilon:
                    action = env.action_space.sample()  # Explore action space, non-greedy (NG) action selection
                else:
                    action = np.argmax(q_table[state])  # Exploit learned values, greedy (G) action selection
                
                decoded_state = list(decode(state))
                print('======ROUND{}=======\n'
                      'app: {}, pod_cpu_util: {}, cpu_threshold: {}, number_of_pods: {}, latency: {}, latency_violation: {}, action: {}'
                      .format(step, current_app_name, decoded_state[0], decoded_state[1], decoded_state[2], 
                              decoded_state[3], int(decoded_state[3] >= 5), action))
                
                real_ob, reward, done, next_state = env.step(action)
                
                now = datetime.datetime.now() + datetime.timedelta(hours=2)
                dt_string = now.strftime('%d/%m/%Y %H:%M:%S')
                dt_dict = {
                    'datetime': dt_string
                }
                info = dt_dict

                (pod_cpu_util,
                 cpu_threshold,
                 number_of_pods,
                 throughput) = real_ob

                # Latency violation becomes 1 if the SLA was violated
                # otherwise it's 0
                throughput_violation = int(throughput > sla_throughput)
                

                # Save historical tuple
                with open('k8s_historical_states_discrete_V1.csv', 'a') as f:
                    f.write(
                        '{},{},{},{},'.format(current_app_name, current_timestep, state, action) +
                        '{},{},{},{},'.format(next_state, reward, done, number_of_pods) +
                        '{},{},{},{},{}'.format(pod_cpu_util, throughput_violation, throughput, cpu_threshold, info) +
                        '\n'
                    )

                with table_lock:
                    old_value = q_table[state, action]
                    # Q-table update is always greedy (np.max)
                    # Q-learning is off-policy since the action taken can be of a different policy (non-greedy, random) (NG)
                    next_max = np.max(q_table[next_state])
                    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
                    q_table[state, action] = new_value
                    
                
                print('reward: {}, new_value: {}'.format(reward, new_value))
                
                print('new cpu utilization: {}, new hpa cpu threshold: {}, new number of pods: {}, new latency: {}, new latency_violation: {}'
                      .format(pod_cpu_util, cpu_threshold, number_of_pods, throughput, throughput_violation)
                      .format(decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
                
                state = next_state
                
                with table_lock:
                    np.save(q_table_file, q_table)

        with table_lock:
            np.save(q_table_file, q_table)

        print('Training finished.\n')

# %%
train_agent(num_of_services)
# Out:
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH0=======
# Training started with cpu utilization: 0, hpa cpu threshold: 0, number of pods: 0, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 0, latency: 2, latency_violation: 0, action: 1
# reward: 0, new_value: 12.375
# new cpu utilization: 0, new hpa cpu threshold: 20, new number of pods: 1, new latency: 0.8955121040344238, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 0, latency: 1, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 25, new_value: 14.875
# new cpu utilization: 0, new hpa cpu threshold: 60, new number of pods: 1, new latency: 0.9296979109446207, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 2, number_of_pods: 0, latency: 1, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 25, new_value: 14.875
# new cpu utilization: 0, new hpa cpu threshold: 100, new number of pods: 1, new latency: 0.9240462779998779, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 4, number_of_pods: 0, latency: 1, latency_violation: 0, action: 4
# reward: 0, new_value: 12.375
# new cpu utilization: 0, new hpa cpu threshold: 100, new number of pods: 1, new latency: 0.91994309425354, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 4, number_of_pods: 0, latency: 1, latency_violation: 0, action: 4
# reward: 0, new_value: 12.262500000000001
# new cpu utilization: 0, new hpa cpu threshold: 100, new number of pods: 1, new latency: 0.9173099199930826, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 4, number_of_pods: 0, latency: 1, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 25, new_value: 14.875
# new cpu utilization: 0, new hpa cpu threshold: 80, new number of pods: 1, new latency: 0.9254076480865479, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 3, number_of_pods: 0, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 25, new_value: 14.875
# new cpu utilization: 0, new hpa cpu threshold: 40, new number of pods: 1, new latency: 0.9160546461741129, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 1, number_of_pods: 0, latency: 1, latency_violation: 0, action: 0
# reward: 0, new_value: 12.375
# new cpu utilization: 0, new hpa cpu threshold: 40, new number of pods: 1, new latency: 0.9177661736806234, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 1, number_of_pods: 0, latency: 1, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 25, new_value: 15.088750000000001
# new cpu utilization: 0, new hpa cpu threshold: 20, new number of pods: 1, new latency: 0.9038635889689127, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 0, number_of_pods: 0, latency: 1, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 25, new_value: 17.22625
# new cpu utilization: 0, new hpa cpu threshold: 60, new number of pods: 1, new latency: 0.9053459167480469, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 2, number_of_pods: 0, latency: 1, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 25, new_value: 17.22625
# new cpu utilization: 0, new hpa cpu threshold: 100, new number of pods: 1, new latency: 0.8832106590270996, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 4, number_of_pods: 0, latency: 1, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 25, new_value: 17.012500000000003
# new cpu utilization: 0, new hpa cpu threshold: 80, new number of pods: 1, new latency: 2.386010726292928, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 3, number_of_pods: 0, latency: 4, latency_violation: 0, action: 2
# reward: 10.818100727112244, new_value: 13.456810072711225
# new cpu utilization: 95, new hpa cpu threshold: 80, new number of pods: 4, new latency: 2.2266337076822915, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.8971595433892143, new_value: 12.764715954338921
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.3361905415852866, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.426646629876401, new_value: 12.71766466298764
# new cpu utilization: 46, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.559211333592733, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH1=======
# Training started with cpu utilization: 2, hpa cpu threshold: 0, number of pods: 4, latency:4
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2
# reward: 3.712195931338427, new_value: 12.746219593133842
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.420472780863444, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.912777512590206, new_value: 12.785867570927909
# new cpu utilization: 45, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.3292580445607505, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.189148563522017, new_value: 13.01554113442459
# new cpu utilization: 46, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.2109580039978027, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 0
# reward: 0, new_value: 12.400728081383512
# new cpu utilization: 42, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.326901912689209, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.169252046025324, new_value: 13.095604720535864
# new cpu utilization: 45, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.219210147857666, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.277453075583909, new_value: 13.32033675338875
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.174800237019857, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# reward: 0, new_value: 12.428604424848228
# new cpu utilization: 41, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.2021047274271646, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.877147423655815, new_value: 13.372589298652846
# new cpu utilization: 44, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.345114231109619, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 0
# reward: 0, new_value: 12.448830307804988
# new cpu utilization: 44, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.1337684790293374, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.8508930198020432, new_value: 13.576925416908836
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.3568915526072183, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 0
# reward: 0, new_value: 12.364188310123918
# new cpu utilization: 48, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.351978143056234, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.031859574517288, new_value: 13.660439613761087
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.277292331059774, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.301651090986445, new_value: 13.878837549555096
# new cpu utilization: 46, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.1650222142537436, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.014271310991779, new_value: 13.944918162944115
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.284870227177938, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.994341600406861, new_value: 14.145430589305242
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.293497165044149, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH2=======
# Training started with cpu utilization: 2, hpa cpu threshold: 0, number of pods: 4, latency:4
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.341474283321848, new_value: 13.109147428332186
# new cpu utilization: 59, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.2875192960103354, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.174791306759238, new_value: 12.922521765340894
# new cpu utilization: 46, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.2169087727864585, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# reward: 0, new_value: 12.440786617028376
# new cpu utilization: 46, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.2734625339508057, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.266899559774007, new_value: 14.250205055664576
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.1790820757548013, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.06176027614848, new_value: 13.281176027614848
# new cpu utilization: 78, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.51942777633667, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.354711893751888, new_value: 12.958559942412661
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.1437723636627197, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.7662297017495687, new_value: 14.390028955559487
# new cpu utilization: 46, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.3954246838887534, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.1509629904338405, new_value: 14.535383455141856
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.2268304030100503, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.056412594838416, new_value: 14.664851830450147
# new cpu utilization: 48, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.26676877339681, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 4
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.64468661661094, new_value: 13.725728306040743
# new cpu utilization: 55, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.161117156346639, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 2
# reward: 7.7093889564836084, new_value: 13.14593889564836
# new cpu utilization: 63, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.1352975368499756, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 2
# reward: 7.7769118579770655, new_value: 13.152691185797707
# new cpu utilization: 65, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.1087563037872314, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 2
# reward: 7.897739389490299, new_value: 13.752196006166965
# new cpu utilization: 52, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.062253793080648, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.9629015342165106, new_value: 12.954474664384419
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.307194471359253, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.433291348729618, new_value: 14.845010909241145
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.1127737363179526, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH3=======
# Training started with cpu utilization: 2, hpa cpu threshold: 1, number of pods: 4, latency:3
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 0
# reward: 0, new_value: 12.569836664740514
# new cpu utilization: 45, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.180327892303467, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.26989403920787, new_value: 14.961407033157622
# new cpu utilization: 42, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.177866061528524, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.456992595869359, new_value: 15.152735710888152
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.1035316785176597, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.535642822438486, new_value: 15.282576826065643
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.073211193084717, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 3
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.473009799892434, new_value: 15.46019503413449
# new cpu utilization: 44, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.097313721974691, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2

# %%
with table_lock:
    np.save(q_table_file, q_table)

# %%
print(q_table[382])
# Out:
# [13.96471286 21.37426449 15.42381685]
