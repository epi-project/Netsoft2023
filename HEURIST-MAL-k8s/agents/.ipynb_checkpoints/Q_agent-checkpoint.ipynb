# %%
# !pip install -e ../gym_k8s_real
# Out:
# ^C
# Traceback (most recent call last):
#   File "/home/li/.local/bin/pip", line 5, in <module>
#     from pip._internal.cli.main import main
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_internal/cli/main.py", line 9, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_internal/cli/autocompletion.py", line 10, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_internal/cli/main_parser.py", line 8, in <module>
#     from pip._internal.cli import cmdoptions
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_internal/cli/cmdoptions.py", line 23, in <module>
#     from pip._internal.cli.parser import ConfigOptionParser
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_internal/cli/parser.py", line 12, in <module>
#     from pip._internal.configuration import Configuration, ConfigurationError
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_internal/configuration.py", line 20, in <module>
#     from pip._internal.exceptions import (
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_internal/exceptions.py", line 13, in <module>
#     from pip._vendor.requests.models import Request, Response
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_vendor/requests/__init__.py", line 43, in <module>
#     from pip._vendor import urllib3
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_vendor/urllib3/__init__.py", line 11, in <module>
#     from . import exceptions
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_vendor/urllib3/exceptions.py", line 3, in <module>
#     from .packages.six.moves.http_client import IncompleteRead as httplib_IncompleteRead
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 982, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 925, in _find_spec
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/six.py", line 192, in find_spec
#     return spec_from_loader(fullname, self)
#   File "<frozen importlib._bootstrap>", line 431, in spec_from_loader
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/six.py", line 222, in is_package
#     return hasattr(self.__get_module(fullname), "__path__")
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/six.py", line 121, in __getattr__
#     _module = self._resolve()
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/six.py", line 118, in _resolve
#     return _import_module(self.mod)
#   File "/home/li/.local/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/six.py", line 87, in _import_module
#     __import__(name)
#   File "/usr/lib/python3.9/http/client.py", line 71, in <module>
#     import email.parser
#   File "/usr/lib/python3.9/email/parser.py", line 12, in <module>
#     from email.feedparser import FeedParser, BytesFeedParser
#   File "/usr/lib/python3.9/email/feedparser.py", line 27, in <module>
#     from email._policybase import compat32
#   File "/usr/lib/python3.9/email/_policybase.py", line 9, in <module>
#     from email.utils import _has_surrogates
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 786, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 881, in get_code
#   File "<frozen importlib._bootstrap_external>", line 980, in get_data
# KeyboardInterrupt

# %%
import gym
import random
import subprocess
import time
import numpy as np
from threading import Lock, Thread
import datetime

# %%
import gym_k8s_real

# %% [markdown]
# ## Info about the kubernetes environment we deploy

# %%
# Timestep duration in minutes
# We wait these many minutes for our actions to be enforced
timestep_duration = 1.5
app_name = 'proxy'
memory_req = '128Mi'
cpu_req = '80m'
sla_throughput = 2.6
prometheus_host = 'http://145.100.135.52:30013'
# Nginx ingress latency metric
# prometheus_throughput_metric_name = '(sum(http_requests_total) by (app))'
prometheus_throughput_metric_name = 'latency'
gym_env = 'gym_k8s_real:k8s-env-discrete-state-discrete-action-v0'
q_table_file = 'Q-env-discrete-state-discrete-action-data.npy'
q_table_init_value = 12.5
total_epochs = 100
num_of_services = 1
steps_per_epoch = 15

# %% [markdown]
# ## Load or create the Q table
# If our Q table file is present, we load in into memory. Otherwise we create a gym environment and using the environment's observation and space dimensions, we create a new one.

# %%
try:
    q_table = np.load(q_table_file)
    print('File present. Loading done!')
    
except IOError:
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=prometheus_throughput_metric_name
    )

    q_table = np.full((env.observation_space.n, env.action_space.n), q_table_init_value)
    np.save(q_table_file, q_table)

    print('File not present. Created successfully!')

table_lock = Lock()
# Out:
# File present. Loading done!

# %% [markdown]
# ## Create historical states csv file if it doesn't exist

# %%
try:
    open('k8s_historical_states_discrete_testing_with_bursts.csv', 'r').close()
    print('File already present.')
except IOError:
    with open('k8s_historical_states_discrete_testing_with_bursts.csv', 'w') as f:
        f.write('current_app_name,timestep,state,action,next_state,reward,'
                'done,number_of_pods,cpu_util,latency_violation,latency,hpa_threshold,info\n')
    print('File not present. Created successfully!')
# Out:
# File already present.

# %% [markdown]
# # Train the agent

# %% [markdown]
# ## Agent training
# This function trains our agent:

# %%
def decode(i):
        out = []
        out.append(i % 7)
        i //= 7
        out.append(i % 5)
        i //= 5
        out.append(i % 5)
        i //= 5
        out.append(i)
        return reversed(out)

# %%
def train_agent(num_service):
    # Hyperparameters
    alpha = 0.1
    gamma = 0.9
    epsilon_init = 0.4
    epsilon_min = 0.2

    current_app_name = app_name
    current_throughput_metric_name = prometheus_throughput_metric_name
    
    env = gym.make(
        gym_env,
        timestep_duration=timestep_duration,
        app_name=current_app_name,
        sla_throughput=sla_throughput,
        prometheus_host=prometheus_host,
        prometheus_throughput_metric_name=current_throughput_metric_name
    )

    for epoch in range(0, total_epochs):
        state, _ = env.reset()
        decoded_state = list(decode(state))
        print('======EPOCH{}=======\n'
              'Training started with cpu utilization: {}, hpa cpu threshold: {}, number of pods: {}, latency:{}'
             .format(epoch, decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
     
        done = False
#         vegeta_process = stress_function(ensdpoint)

        for step in range(steps_per_epoch):
            current_timestep = epoch * steps_per_epoch + step
            q_table = np.load(q_table_file)
            
            # Epsilon keeps getting smaller and stops when it reaches epsilon_min
            current_epsilon = pow(epsilon_init, current_timestep)
            epsilon = max(current_epsilon, epsilon_min)
            
            if done:
                break
            else:    
                if random.uniform(0, 1) < epsilon:
                    action = env.action_space.sample()  # Explore action space, non-greedy (NG) action selection
                else:
                    action = np.argmax(q_table[state])  # Exploit learned values, greedy (G) action selection
                
                decoded_state = list(decode(state))
                print('======ROUND{}=======\n'
                      'app: {}, pod_cpu_util: {}, cpu_threshold: {}, number_of_pods: {}, latency: {}, latency_violation: {}, action: {}'
                      .format(step, current_app_name, decoded_state[0], decoded_state[1], decoded_state[2], 
                              decoded_state[3], int(decoded_state[3] >= 5), action))
                
                real_ob, reward, done, next_state = env.step(action)
                
                now = datetime.datetime.now() + datetime.timedelta(hours=2)
                dt_string = now.strftime('%d/%m/%Y %H:%M:%S')
                dt_dict = {
                    'datetime': dt_string
                }
                info = dt_dict

                (pod_cpu_util,
                 cpu_threshold,
                 number_of_pods,
                 throughput) = real_ob

                # Latency violation becomes 1 if the SLA was violated
                # otherwise it's 0
                throughput_violation = int(throughput > sla_throughput)
                

                # Save historical tuple
                with open('k8s_historical_states_discrete_testing_with_bursts.csv', 'a') as f:
                    f.write(
                        '{},{},{},{},'.format(current_app_name, current_timestep, state, action) +
                        '{},{},{},{},'.format(next_state, reward, done, number_of_pods) +
                        '{},{},{},{},{}'.format(pod_cpu_util, throughput_violation, throughput, cpu_threshold, info) +
                        '\n'
                    )

                with table_lock:
                    old_value = q_table[state, action]
                    # Q-table update is always greedy (np.max)
                    # Q-learning is off-policy since the action taken can be of a different policy (non-greedy, random) (NG)
                    next_max = np.max(q_table[next_state])
                    new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
                    q_table[state, action] = new_value
                    
                
                print('reward: {}, new_value: {}'.format(reward, new_value))
                
                print('new cpu utilization: {}, new hpa cpu threshold: {}, new number of pods: {}, new latency: {}, new latency_violation: {}'
                      .format(pod_cpu_util, cpu_threshold, number_of_pods, throughput, throughput_violation)
                      .format(decoded_state[0], decoded_state[1], decoded_state[2], decoded_state[3]))
                
                state = next_state
                
                with table_lock:
                    np.save(q_table_file, q_table)

        with table_lock:
            np.save(q_table_file, q_table)

        print('Training finished.\n')

# %%
train_agent(num_of_services)
# Out:
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH0=======
# Training started with cpu utilization: 0, hpa cpu threshold: 3, number of pods: 0, latency:1
# ======ROUND0=======
# app: proxy, pod_cpu_util: 0, cpu_threshold: 3, number_of_pods: 0, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 17.25473485841023, new_value: 21.95558846630707
# new cpu utilization: 113, new hpa cpu threshold: 60, new number of pods: 2, new latency: 1.0120807488759358, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 2, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.243223727227807, new_value: 13.199322372722781
# new cpu utilization: 57, new hpa cpu threshold: 40, new number of pods: 6, new latency: 2.3805087407430015, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.549026952819041, new_value: 15.278785908138595
# new cpu utilization: 33, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4364717801411946, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.180804005166214, new_value: 36.79663110096091
# new cpu utilization: 66, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.9981544017791748, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.165605370960092, new_value: 23.89042296225658
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.2207268873850503, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.295464418503771, new_value: 24.80456081834781
# new cpu utilization: 78, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.9968559741973877, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.081212332855406, new_value: 33.169416174808305
# new cpu utilization: 46, new hpa cpu threshold: 60, new number of pods: 6, new latency: 2.4560550848642984, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 1
# reward: 7.18767898852131, new_value: 25.78580786625394
# new cpu utilization: 48, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.355338176091512, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.365842695608407, new_value: 16.199436302797373
# new cpu utilization: 54, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.139347553253174, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.514487888406496, new_value: 25.831155521315427
# new cpu utilization: 86, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.3089314301808677, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 9.60604976676413, new_value: 28.893519580828055
# new cpu utilization: 77, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.269299586613973, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 9.844405614843275, new_value: 27.35380376910037
# new cpu utilization: 81, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.170188029607137, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 9.716292716792697, new_value: 29.43763923364355
# new cpu utilization: 72, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.2227537631988525, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 9.942875791223472, new_value: 28.074553310531716
# new cpu utilization: 70, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.1308414141337075, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 9.993401976663979, new_value: 28.7931479750928
# new cpu utilization: 70, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.1109937032063804, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH1=======
# Training started with cpu utilization: 3, hpa cpu threshold: 3, number of pods: 2, latency:4
# ======ROUND0=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 9.903967073683294, new_value: 29.55361741597977
# new cpu utilization: 80, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.1462819576263428, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.359882159892122, new_value: 15.79820394088358
# new cpu utilization: 56, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.5805845260620117, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.07914297558558, new_value: 32.63854407602392
# new cpu utilization: 95, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.8028154373168945, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.650105862912085, new_value: 31.179864040233838
# new cpu utilization: 108, new hpa cpu threshold: 80, new number of pods: 4, new latency: 2.298234701156616, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.25904728963052, new_value: 13.22521046887379
# new cpu utilization: 106, new hpa cpu threshold: 60, new number of pods: 6, new latency: 2.3733036518096924, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.166749411662074, new_value: 13.434732340273587
# new cpu utilization: 108, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.3073201179504395, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.9754062894085385, new_value: 15.259237428027337
# new cpu utilization: 30, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.3271433512369792, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.077808619577873, new_value: 36.87613638595297
# new cpu utilization: 42, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.170904000600179, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.271828323945062, new_value: 29.79303255000361
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.3363398710886638, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.101163753809903, new_value: 36.64871251317184
# new cpu utilization: 27, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.0678069591522217, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.31326247637821, new_value: 37.695971319710196
# new cpu utilization: 44, new hpa cpu threshold: 60, new number of pods: 5, new latency: 0.9327345689137777, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 17.746309892491304, new_value: 19.506819017078858
# new cpu utilization: 80, new hpa cpu threshold: 100, new number of pods: 2, new latency: 0.9131105740865072, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.91313817566389, new_value: 24.51728144307891
# new cpu utilization: 80, new hpa cpu threshold: 80, new number of pods: 3, new latency: 1.2878448963165283, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 1, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.665155977382014, new_value: 25.96849622542981
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.2941138744354248, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 13.269935497072067, new_value: 39.53221130915524
# new cpu utilization: 50, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.1526044209798176, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH2=======
# Training started with cpu utilization: 2, hpa cpu threshold: 2, number of pods: 2, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.087811028500655, new_value: 35.500944061268356
# new cpu utilization: 46, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.253403663635254, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.228357541777342, new_value: 26.276021089806164
# new cpu utilization: 56, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.4040179252624512, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.845910970514721, new_value: 22.531129727011066
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.2505963643391926, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 11.409911425951945, new_value: 19.793540060188395
# new cpu utilization: 69, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.6308313210805256, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.524387759312031, new_value: 28.76852737387111
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.503071943918864, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.618040532502683, new_value: 34.59144295490374
# new cpu utilization: 30, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4183015028635662, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.237495673838827, new_value: 38.70802277294703
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.40164581934611, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 12.622983591068422, new_value: 40.39918755517053
# new cpu utilization: 66, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.3044261932373047, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 11.014034649270492, new_value: 40.14204519408085
# new cpu utilization: 57, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.4310378233591716, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.021918082856006, new_value: 29.580763001371405
# new cpu utilization: 49, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.281571547190348, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.264127926868056, new_value: 27.91085616926804
# new cpu utilization: 61, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.394750992457072, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.45964319365332, new_value: 34.09537574057058
# new cpu utilization: 70, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.6161691347757976, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.821770693397076, new_value: 29.68708157176504
# new cpu utilization: 48, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.365747292836507, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.628325763447743, new_value: 34.55406845036048
# new cpu utilization: 37, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.6990795135498047, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.872713750631217, new_value: 32.514112487928664
# new cpu utilization: 56, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.7618117332458496, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH3=======
# Training started with cpu utilization: 2, hpa cpu threshold: 2, number of pods: 3, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.020085798706683, new_value: 30.106170242166414
# new cpu utilization: 39, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.0852418740590413, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.174413283119833, new_value: 28.96161270937473
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.2170657316843667, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.126699433826369, new_value: 21.144356614704474
# new cpu utilization: 52, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.648983637491862, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.634314434923695, new_value: 33.544308875534945
# new cpu utilization: 100, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.6301857630411785, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.72671505013996, new_value: 30.15954914122445
# new cpu utilization: 98, new hpa cpu threshold: 80, new number of pods: 6, new latency: 1.8090698719024658, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 3, latency: 3, latency_violation: 0, action: 1
# reward: 9.328725460896466, new_value: 14.842698113527826
# new cpu utilization: 61, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.3922335306803384, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 10.070297619546047, new_value: 30.254672967364318
# new cpu utilization: 84, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.081217050552368, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 11.560683869833646, new_value: 30.63519115299531
# new cpu utilization: 72, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.5867563883463542, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.57532781263442, new_value: 32.88342337382277
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.5197007656097412, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 1
# reward: 6.7132172798993395, new_value: 16.523544694416398
# new cpu utilization: 50, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.5830286343892417, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 1
# reward: 9.830830077988784, new_value: 26.8998654092224
# new cpu utilization: 54, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.4501642386118572, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.3954991127806196, new_value: 30.94496928976028
# new cpu utilization: 47, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.5079683462778728, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.454024262547181, new_value: 33.59724367289354
# new cpu utilization: 40, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.4618003368377686, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 1
# reward: 5.832102450725266, new_value: 21.669532354943243
# new cpu utilization: 43, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.63743257522583, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.116191917626942, new_value: 29.441923395109736
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.4042918682098389, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH4=======
# Training started with cpu utilization: 2, hpa cpu threshold: 2, number of pods: 3, latency:3
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.348123066548267, new_value: 34.239049717346475
# new cpu utilization: 82, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.7170281410217285, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.469683464534054, new_value: 30.533833372371163
# new cpu utilization: 98, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.3424378236134846, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 2
# reward: 0, new_value: 14.085324240025647
# new cpu utilization: 98, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.3940893809000652, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 10.792885229631239, new_value: 15.288796626607173
# new cpu utilization: 76, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.8238799571990967, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.340063200729894, new_value: 33.61060183107467
# new cpu utilization: 55, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.586294174194336, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.721078029525074, new_value: 34.45481480149076
# new cpu utilization: 86, new hpa cpu threshold: 100, new number of pods: 4, new latency: 1.8855005900065105, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.930764355182848, new_value: 28.39161953184532
# new cpu utilization: 74, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.1356329917907715, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 10.694053172379258, new_value: 31.323565152662535
# new cpu utilization: 74, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.85690172513326, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.376870882237876, new_value: 32.165265850362374
# new cpu utilization: 67, new hpa cpu threshold: 60, new number of pods: 8, new latency: 2.2252920468648276, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 4, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.04808528797916, new_value: 14.750310216682642
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.2703307469685874, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.05095220795406, new_value: 18.199578711725643
# new cpu utilization: 37, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.2691036065419516, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.289536672057265, new_value: 16.103837172203235
# new cpu utilization: 55, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.633576234181722, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.519992831469338, new_value: 19.43125718211014
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.4441733360290527, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.702398923271419, new_value: 30.198031465452786
# new cpu utilization: 33, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9437158902486166, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.047788037654762, new_value: 37.54096421811663
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.2032512029012044, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH5=======
# Training started with cpu utilization: 3, hpa cpu threshold: 2, number of pods: 2, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 12.440463089832328, new_value: 40.56697194917015
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.3497787316640217, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.759276263426006, new_value: 35.85504155074172
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.2186555862426758, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.768340418355372, new_value: 31.787278409842507
# new cpu utilization: 53, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.0676978429158528, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.618550610913678, new_value: 24.966825554968082
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.1000449657440186, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.012021104167946, new_value: 36.29274327030609
# new cpu utilization: 33, new hpa cpu threshold: 40, new number of pods: 6, new latency: 0.970779816309611, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.0515425169547665, new_value: 29.76836992313461
# new cpu utilization: 30, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.2688510417938232, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# reward: 8.507676382148121, new_value: 25.66123471006202
# new cpu utilization: 37, new hpa cpu threshold: 20, new number of pods: 10, new latency: 0.9829409917195638, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.956820157127492, new_value: 36.93268787862081
# new cpu utilization: 62, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.7351611455281575, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.368664058547265, new_value: 24.336792172632254
# new cpu utilization: 42, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.7809499104817708, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 4.0511195586924, new_value: 25.700074087240875
# new cpu utilization: 36, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.2690320014953613, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 0
# reward: 0, new_value: 13.116028892030037
# new cpu utilization: 44, new hpa cpu threshold: 20, new number of pods: 10, new latency: 2.163422425587972, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.75093708721376, new_value: 22.326002548785418
# new cpu utilization: 50, new hpa cpu threshold: 60, new number of pods: 6, new latency: 2.163072427113851, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 1
# reward: 7.204779370728978, new_value: 27.351344692203078
# new cpu utilization: 55, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.347664992014567, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 1
# reward: 8.858281810866938, new_value: 27.588008620165045
# new cpu utilization: 63, new hpa cpu threshold: 60, new number of pods: 6, new latency: 2.120396614074707, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 1
# reward: 7.426666067739975, new_value: 24.08528954354464
# new cpu utilization: 48, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.251063903172811, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH6=======
# Training started with cpu utilization: 2, hpa cpu threshold: 2, number of pods: 3, latency:4
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 1
# reward: 7.827472881382226, new_value: 28.09487582210162
# new cpu utilization: 54, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.089145024617513, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 1
# reward: 7.72583421650169, new_value: 28.22564772046065
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 7, new latency: 2.128795862197876, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 4, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.449828003377156, new_value: 15.577469791766426
# new cpu utilization: 93, new hpa cpu threshold: 100, new number of pods: 3, new latency: 2.4393200874328613, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.315126140256178, new_value: 22.830728346082303
# new cpu utilization: 90, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.9896807670593262, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 1
# reward: 11.032964226147788, new_value: 31.115687297833972
# new cpu utilization: 62, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.7461913426717122, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.050531040323716, new_value: 30.986499524651204
# new cpu utilization: 57, new hpa cpu threshold: 60, new number of pods: 8, new latency: 1.9648268222808838, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.80085604773225, new_value: 13.555085604773225
# new cpu utilization: 106, new hpa cpu threshold: 100, new number of pods: 4, new latency: 1.8583556016286213, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 4, number_of_pods: 2, latency: 3, latency_violation: 0, action: 2
# reward: 0, new_value: 12.375
# new cpu utilization: 106, new hpa cpu threshold: 100, new number of pods: 4, new latency: 1.7217764854431152, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 5, cpu_threshold: 4, number_of_pods: 2, latency: 3, latency_violation: 0, action: 1
# reward: 12.830040779611753, new_value: 14.228872369739713
# new cpu utilization: 86, new hpa cpu threshold: 100, new number of pods: 4, new latency: 1.5416714350382488, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.923533014180801, new_value: 20.770157082943093
# new cpu utilization: 72, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.138500213623047, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 10.724375786962197, new_value: 32.08276707983213
# new cpu utilization: 71, new hpa cpu threshold: 80, new number of pods: 4, new latency: 2.2662148475646973, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 12.560479589777735, new_value: 32.37755263077382
# new cpu utilization: 58, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.3198239008585613, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.049416484290774, new_value: 27.426112123325666
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.2028745015462239, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 11.448400344297063, new_value: 39.7285308239147
# new cpu utilization: 66, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.064834753672282, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.007852298228137, new_value: 25.072342167014234
# new cpu utilization: 64, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.0404422283172607, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH7=======
# Training started with cpu utilization: 3, hpa cpu threshold: 4, number of pods: 1, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 4, number_of_pods: 1, latency: 2, latency_violation: 0, action: 1
# reward: 16.179615538690143, new_value: 31.198482732474588
# new cpu utilization: 91, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.0046395460764568, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 16.36753073215546, new_value: 26.900306600576112
# new cpu utilization: 68, new hpa cpu threshold: 80, new number of pods: 3, new latency: 0.9662990570068359, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 1, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.82047915806876, new_value: 36.628397096029865
# new cpu utilization: 46, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.2833682696024578, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.196267993014569, new_value: 36.495448222606164
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 6, new latency: 0.9338994026184082, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 1, latency_violation: 0, action: 1
# reward: 11.595699646322188, new_value: 15.270425021518044
# new cpu utilization: 33, new hpa cpu threshold: 40, new number of pods: 6, new latency: 1.2839879989624023, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.79773020532484, new_value: 33.05690740604209
# new cpu utilization: 68, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.2888890107472737, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.481261296485446, new_value: 33.42510789416443
# new cpu utilization: 76, new hpa cpu threshold: 60, new number of pods: 5, new latency: 2.323540369669596, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 4, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.6353114048166155, new_value: 21.392789952395994
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.170461893081665, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.851874709008647, new_value: 31.347137839373605
# new cpu utilization: 28, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.3581150372823079, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.932095819793638, new_value: 39.70599785178402
# new cpu utilization: 60, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.2302254835764568, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 12.951065472724014, new_value: 40.62635206294796
# new cpu utilization: 61, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.2257737318674724, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 12.768099799078662, new_value: 41.12511717659559
# new cpu utilization: 57, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.2691959540049236, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.665440702369972, new_value: 37.21083159676801
# new cpu utilization: 41, new hpa cpu threshold: 40, new number of pods: 7, new latency: 1.2406978607177734, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.8878385330746745, new_value: 37.24616492182269
# new cpu utilization: 36, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.3490409851074219, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.43505395300556, new_value: 39.6639506979846
# new cpu utilization: 51, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.3233695824940999, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH8=======
# Training started with cpu utilization: 2, hpa cpu threshold: 2, number of pods: 3, latency:2
# ======ROUND0=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.446261881049477, new_value: 30.04674818053801
# new cpu utilization: 37, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.618813912073771, new latency_violation: 1
# ======ROUND1=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 5, latency_violation: 1, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.27948696652539, new_value: 15.714200575959271
# new cpu utilization: 33, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.5093206564585369, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.858490909299174, new_value: 40.23237956282518
# new cpu utilization: 57, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.5028602282206218, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.112829518293168, new_value: 36.802651540999584
# new cpu utilization: 39, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.5559447606404622, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.31371060477481, new_value: 30.531448502940652
# new cpu utilization: 61, new hpa cpu threshold: 80, new number of pods: 5, new latency: 0.9326458772023519, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 1, latency_violation: 0, action: 1
# reward: 13.387958697876678, new_value: 25.18581479698837
# new cpu utilization: 66, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.3914676507314045, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.424325037935475, new_value: 33.31534090407844
# new cpu utilization: 62, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.5940593083699544, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 3.692497156014625, new_value: 24.784339726204614
# new cpu utilization: 43, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.429695208867391, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 4, latency_violation: 0, action: 1
# reward: 5.237236504412245, new_value: 15.020857320608188
# new cpu utilization: 34, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.8239107926686604, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.562054102733242, new_value: 31.348488799689555
# new cpu utilization: 66, new hpa cpu threshold: 80, new number of pods: 5, new latency: 2.2882297039031982, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 10.765289672209445, new_value: 33.00511129213599
# new cpu utilization: 64, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.8330370585123699, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.247229886213745, new_value: 31.81677989705588
# new cpu utilization: 46, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.132853666941325, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.613605593446332, new_value: 28.981873382678206
# new cpu utilization: 63, new hpa cpu threshold: 40, new number of pods: 10, new latency: 1.7036187648773193, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 1
# reward: 4.704764929304463, new_value: 14.033483160782126
# new cpu utilization: 58, new hpa cpu threshold: 40, new number of pods: 10, new latency: 2.0097556114196777, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 5.388238199389445, new_value: 26.595160622369313
# new cpu utilization: 39, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.7746416727701824, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH9=======
# Training started with cpu utilization: 1, hpa cpu threshold: 0, number of pods: 4, latency:4
# ======ROUND0=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 4, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 9.064435182093863, new_value: 18.500830305326467
# new cpu utilization: 53, new hpa cpu threshold: 60, new number of pods: 7, new latency: 1.6677134831746419, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.043352528208255, new_value: 35.06171357767592
# new cpu utilization: 91, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.814557154973348, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 15.415332398990985, new_value: 30.376442524946
# new cpu utilization: 23, new hpa cpu threshold: 80, new number of pods: 4, new latency: 0.934524933497111, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 3, number_of_pods: 2, latency: 1, latency_violation: 0, action: 2
# reward: 0, new_value: 12.604459249912853
# new cpu utilization: 23, new hpa cpu threshold: 80, new number of pods: 4, new latency: 0.9177869160970052, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 3, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.85210403371668, new_value: 16.114203567244648
# new cpu utilization: 100, new hpa cpu threshold: 60, new number of pods: 4, new latency: 1.535477638244629, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 1
# reward: 11.477612261340713, new_value: 15.069598567592925
# new cpu utilization: 64, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.6109017531077068, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 7.073099759306377, new_value: 30.247047382491235
# new cpu utilization: 34, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.599253257115682, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.785598657900987, new_value: 32.26265980180294
# new cpu utilization: 78, new hpa cpu threshold: 80, new number of pods: 4, new latency: 2.2402575810750327, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 4, latency_violation: 0, action: 1
# reward: 11.406385173034735, new_value: 33.708748870960896
# new cpu utilization: 71, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.6318756739298503, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.304775030759457, new_value: 32.2596300335468
# new cpu utilization: 58, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.6622425715128581, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 3, latency_violation: 0, action: 1
# reward: 13.065623139922067, new_value: 15.366654359536607
# new cpu utilization: 62, new hpa cpu threshold: 60, new number of pods: 6, new latency: 0.9599692026774088, new latency_violation: 0
# ======ROUND11=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 1, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.483328180714253, new_value: 15.232212645316565
# new cpu utilization: 86, new hpa cpu threshold: 100, new number of pods: 3, new latency: 2.0094662507375083, new latency_violation: 0
# ======ROUND12=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.789023440489725, new_value: 31.32106731951959
# new cpu utilization: 66, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.8251585165659587, new latency_violation: 0
# ======ROUND13=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.855542434327909, new_value: 32.47573206865619
# new cpu utilization: 63, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.2221240997314453, new latency_violation: 0
# ======ROUND14=======
# app: proxy, pod_cpu_util: 3, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.823219833257879, new_value: 26.66632599239536
# new cpu utilization: 84, new hpa cpu threshold: 100, new number of pods: 3, new latency: 1.8885792096455891, new latency_violation: 0
# Training finished.
#
# Created new namespaced_horizontal_pod_autoscaler
# ======EPOCH10=======
# Training started with cpu utilization: 4, hpa cpu threshold: 4, number of pods: 1, latency:3
# ======ROUND0=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 4, number_of_pods: 1, latency: 3, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.476328631781389, new_value: 32.13700530755083
# new cpu utilization: 85, new hpa cpu threshold: 80, new number of pods: 5, new latency: 1.6112775007883708, new latency_violation: 0
# ======ROUND1=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 3, latency_violation: 0, action: 1
# reward: 13.700821815577244, new_value: 31.517471548424055
# new cpu utilization: 80, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.312605857849121, new latency_violation: 0
# ======ROUND2=======
# app: proxy, pod_cpu_util: 4, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.985202051843817, new_value: 25.13959679778297
# new cpu utilization: 56, new hpa cpu threshold: 60, new number of pods: 6, new latency: 1.438661813735962, new latency_violation: 0
# ======ROUND3=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 3, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 6.954606837332359, new_value: 29.682786110305884
# new cpu utilization: 34, new hpa cpu threshold: 40, new number of pods: 9, new latency: 1.6340497334798176, new latency_violation: 0
# ======ROUND4=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 4, latency: 3, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 13.411831425175048, new_value: 32.84592705523946
# new cpu utilization: 58, new hpa cpu threshold: 80, new number of pods: 4, new latency: 1.385322093963623, new latency_violation: 0
# ======ROUND5=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 3, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 11.926545021526671, new_value: 29.18839405183573
# new cpu utilization: 55, new hpa cpu threshold: 60, new number of pods: 5, new latency: 1.4842453797658284, new latency_violation: 0
# ======ROUND6=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 10.396453719427646, new_value: 37.18578368940281
# new cpu utilization: 40, new hpa cpu threshold: 40, new number of pods: 8, new latency: 1.0522433916727703, new latency_violation: 0
# ======ROUND7=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 1, number_of_pods: 4, latency: 2, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 8.262780576676281, new_value: 34.68471152392608
# new cpu utilization: 24, new hpa cpu threshold: 20, new number of pods: 10, new latency: 1.0335676670074463, new latency_violation: 0
# ======ROUND8=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 0, number_of_pods: 4, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 14.09399605197076, new_value: 40.69466353645444
# new cpu utilization: 41, new hpa cpu threshold: 60, new number of pods: 5, new latency: 0.9766844908396403, new latency_violation: 0
# ======ROUND9=======
# app: proxy, pod_cpu_util: 2, cpu_threshold: 2, number_of_pods: 2, latency: 1, latency_violation: 0, action: 0
# Created new namespaced_horizontal_pod_autoscaler without exception
# reward: 12.38822727984737, new_value: 34.97516764167556
# new cpu utilization: 32, new hpa cpu threshold: 40, new number of pods: 6, new latency: 1.1018117268880208, new latency_violation: 0
# ======ROUND10=======
# app: proxy, pod_cpu_util: 1, cpu_threshold: 1, number_of_pods: 3, latency: 2, latency_violation: 0, action: 2
# Created new namespaced_horizontal_pod_autoscaler without exception

# %%
with table_lock:
    np.save(q_table_file, q_table)

# %%
print(q_table[382])
# Out:
# [13.96471286 21.37426449 15.42381685]
